# %%
### 필요 라이브러리
import os
import pandas as pd
import numpy as np
import datetime as dt
import math
import warnings
warnings.filterwarnings(action='ignore')
# save numpy array as npy file
from numpy import asarray
from numpy import save
### 데이터 보여지는 개수 설정
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_rows', 300)

# %%
### 폴더에 존재하는 파일 리스트, 굳이 실행하지 않아도 됨
# path_dir = 'C:/Users/HONGJEONGUI/Desktop/RA/Data/DataOR'
path_dir = '/Data/Data'
 
file_list = os.listdir(path_dir)
print(file_list)
# Out:
# ['PT구분코드(전체조회기간).xlsx', 'stktrd_20150102.csv', 'ord201709', 'stkord_20150102.csv.gz', 'ORD_19990104.csv', 'layout_3.csv', '시장정보 데이터 확인 및 요청_레이아웃.xlsx', 'layout_2.csv', '유가 체결장 2단계 샘플.csv', 'layout_1.csv', 'SPOT_TRD_20130102.csv', 'ord', '유가 호가장 2단계 샘플.csv', '코스닥 체결장 2단계 샘플.csv', 'TRD_19990104.csv', '코스닥 호가장 2단계 샘플.csv', 'ksqtrd_20150102.csv']

# %%
### 유재인 교수님께서 공유해주신 레이블, 코드 설명 엑셀파일(xlsx)을 (시트가 3개) 각 시트별로 csv로 저장.
### 1번째 위치는 엑셀파일위치, 2,3번째는 코드 저장 위치


sheets = 3
for i in range(1,sheets+1):
    df = pd.read_excel(path_dir+"/시장정보 데이터 확인 및 요청_레이아웃.xlsx", sheet_name=(i-1))
    df.to_csv((path_dir+"/layout_{}.csv").format(i), encoding = "cp949", sep=',', header = False, index = False)
    globals()['layout_{}'.format(i)] = pd.read_csv((path_dir+"/layout_{}.csv").format(i), header = None, encoding="cp949")

# %%
df = pd.read_csv(path_dir+"/코스닥 호가장 2단계 샘플.csv",encoding='cp949')

# %%
header_df=['ISU_CD', 'ORD_DD', 'ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD', 'BLKTRD_TP_CD', '호가장처리가격',
       'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 'ORD_COND_CD', 'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC',
       'ASK_STEP1_BSTORD_RQTY', 'ASK_STEP2_BSTORD_PRC','ASK_STEP2_BSTORD_RQTY','ASK_STEP3_BSTORD_PRC',
       'ASK_STEP3_BSTORD_RQTY','ASK_STEP4_BSTORD_PRC', 'ASK_STEP4_BSTORD_RQTY','ASK_STEP5_BSTORD_PRC',
       'ASK_STEP5_BSTORD_RQTY',
       'BID_STEP1_BSTORD_PRC', 'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC', 'BID_STEP2_BSTORD_RQTY',
       'BID_STEP3_BSTORD_PRC', 'BID_STEP3_BSTORD_RQTY','BID_STEP4_BSTORD_PRC', 'BID_STEP4_BSTORD_RQTY',
       'BID_STEP5_BSTORD_PRC', 'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
       '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD', 'FORNINVST_TP_CD',
       'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량', '매도총호가잔량', '매수총호가잔량',
       '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금', 'AGG_TM', '시가', '고가', '저가',
       'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드', 'MKTSTAT_TP_CD', '매도10단계호가합계잔량',
       '매수10단계호가합계잔량', 'PT_TP_CD']
header = header_df

 
df.columns=header_df
df=df[1:]
df.head()
# Out:
#          ISU_CD    ORD_DD ORD_ACPT_NO REGUL_OFFHR_TP_CD BLKTRD_TP_CD 호가장처리가격  \
# 1  KR7009620006  20171030       23650                 1            0   19550
# 2  KR7009620006  20171030       23651                 1            0   19500
# 3  KR7009620006  20171030       23652                 1            0   19550
# 4  KR7009620006  20171030       23653                 1            0   19250
# 5  KR7009620006  20171030       23654                 1            0   19600
#
#   ASKBID_TP_CD MODCANCL_TP_CD ORD_TP_CD ORD_COND_CD INVST_TP_CD  \
# 1            2              1         2           0        8000
# 2            1              1         2           0        8000
# 3            1              1         2           0        8000
# 4            2              1         2           0        8000
# 5            2              2         2           0        8000
#
#   ASK_STEP1_BSTORD_PRC ASK_STEP1_BSTORD_RQTY ASK_STEP2_BSTORD_PRC  \
# 1                19650                     5                19700
# 2                19650                     5                19700
# 3                19650                     5                19700
# 4                19650                     5                19700
# 5                19650                     5                19700
#
#   ASK_STEP2_BSTORD_RQTY ASK_STEP3_BSTORD_PRC ASK_STEP3_BSTORD_RQTY  \
# 1                   582                19750                   385
# 2                   582                19750                   385
# 3                   582                19750                   385
# 4                   582                19750                   385
# 5                   582                19750                   385
#
#   ASK_STEP4_BSTORD_PRC ASK_STEP4_BSTORD_RQTY ASK_STEP5_BSTORD_PRC  ...  \
# 1                19800                   609                19850  ...
# 2                19800                   609                19850  ...
# 3                19800                   609                19850  ...
# 4                19800                   609                19850  ...
# 5                19800                   609                19850  ...
#
#      회원사주문시각 예상체결가격 예상체결수량 매도총호가잔량 매수총호가잔량 호가체결접수순서번호 직전체결가격 누적체결수량   누적거래대금  \
# 1  125949640      0      0   21901   29871      34709  19550      0        0
# 2  125949734      0      0   21901   29871      34710  19550     77  1505350
# 3  125950114      0      0   21901   29794      34712  19550      5    97750
# 4  125950375      0      0   21901   29919      34714  19550    130  2502500
# 5  125950687      0      0   21901   29919      34715  19550      0        0
#
#       AGG_TM     시가     고가     저가 ORGN_ORD_ACPT_NO 시장구분코드 자동취소처리구분코드  \
# 1          0  15350  19850  14400                0      2          0
# 2  125949735  15350  19850  14400                0      2          0
# 3  125950115  15350  19850  14400                0      2          0
# 4  130058726  15350  19850  14400                0      2          0
# 5          0  15350  19850  14400            23599      2          0
#
#   MKTSTAT_TP_CD 매도10단계호가합계잔량 매수10단계호가합계잔량 PT_TP_CD
# 1            40         4465         4210        0
# 2            40         4465         4210        0
# 3            40         4465         4133        0
# 4            40         4465         4258        0
# 5            40         4465         3432        0
#
# [5 rows x 61 columns]

# %%
data_dir=path_dir+'/'+'ord'

UUID_count={}
file_list = os.listdir(data_dir)
print(file_list)
columnlist=['MBR_NO','BRN_NO']
filecount=0
for filename in file_list:
    print(filename)
    df1 = pd.read_csv(data_dir+'/'+filename, sep=',', header=None, encoding="cp949")
    break
    if 'SPOT' in filename:
        df1.columns = list(layout_1.iloc[0:len(df1.iloc[0])][0])
        print("Using 2013 data")
    else:
        continue
    if(filecount==0):
        countdf=df1.groupby(columnlist).size()
    else:
        countdf=countdf.add(df1.groupby(columnlist).size())
    filecount+=1
    break
# Out:
# ['SPOT_ORD_20130102.csv', 'ksqord_20150102.csv']
# SPOT_ORD_20130102.csv

# %%
df1.columns = list(layout_1.iloc[0:len(df1.iloc[0])][0])

# %%
df2013=df1

# %%
mbrnlist1=[(5,194),(2,155),(12,100),(17,29),(42,1),(44,1),(50,92),(2,83),(4,10118),(8,298)]
mbrnlist2=[(5,194),(12,100),(2,155),(17,29),(42,1),(44,1),(2,83),(4,10118),(4,9997),(50,91)]
mbrnlist=mbrnlist1+mbrnlist2
mbrnlist=set(mbrnlist)
mbrnlist=list(mbrnlist)

# %%
mbrnlist
# Out:
# [(44, 1),
#  (2, 83),
#  (4, 10118),
#  (17, 29),
#  (50, 91),
#  (8, 298),
#  (4, 9997),
#  (5, 194),
#  (12, 100),
#  (50, 92),
#  (42, 1),
#  (2, 155)]

# %%
MBR_NO,BRN_NO=12,100
for MBR_NO,BRN_NO in mbrnlist1:
    print(MBR_NO,BRN_NO,df2013[(df2013['MBR_NO']==MBR_NO)]['MKTPARTC_KOR_ABBRV'].head(1))
# Out:
# 5 194 5    대우증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 2 155 53    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 12 100 7    NH투자증권(우리)
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 17 29 36    현대증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 42 1 172    CS증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 44 1 282    메릴린치
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 50 92 4    키움증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 2 83 53    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 4 10118 67    대신증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object
# 8 298 273    유진증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object

# %%
MBR_NO,BRN_NO=12,100
for MBR_NO,BRN_NO in mbrnlist1:
    print(MBR_NO,BRN_NO,df2013[(df2013['MBR_NO']==MBR_NO)&(df2013['BRN_NO']==BRN_NO)]['MKTPARTC_KOR_ABBRV'].head(1),
         df2013[(df2013['MBR_NO']==MBR_NO)&(df2013['BRN_NO']==BRN_NO)]['BRN_NM'].head(1))
# Out:
# 5 194 Series([], Name: MKTPARTC_KOR_ABBRV, dtype: object) Series([], Name: BRN_NM, dtype: object)
# 2 155 364    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object 364    영업10부
# Name: BRN_NM, dtype: object
# 12 100 8    NH투자증권(우리)
# Name: MKTPARTC_KOR_ABBRV, dtype: object 8    스마트
# Name: BRN_NM, dtype: object
# 17 29 4939    현대증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 4939    YF사이버
# Name: BRN_NM, dtype: object
# 42 1 172    CS증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 172    고객
# Name: BRN_NM, dtype: object
# 44 1 282    메릴린치
# Name: MKTPARTC_KOR_ABBRV, dtype: object 282    서울
# Name: BRN_NM, dtype: object
# 50 92 Series([], Name: MKTPARTC_KOR_ABBRV, dtype: object) Series([], Name: BRN_NM, dtype: object)
# 2 83 860    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object 860    신한은행
# Name: BRN_NM, dtype: object
# 4 10118 44434    대신증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 44434    다이렉트지점
# Name: BRN_NM, dtype: object
# 8 298 Series([], Name: MKTPARTC_KOR_ABBRV, dtype: object) Series([], Name: BRN_NM, dtype: object)

# %%
for MBR_NO,BRN_NO in mbrnlist2:
    print(MBR_NO,BRN_NO,df2013[(df2013['MBR_NO']==MBR_NO)&(df2013['BRN_NO']==BRN_NO)]['MKTPARTC_KOR_ABBRV'].head(1),
         df2013[(df2013['MBR_NO']==MBR_NO)&(df2013['BRN_NO']==BRN_NO)]['BRN_NM'].head(1))
# Out:
# 5 194 Series([], Name: MKTPARTC_KOR_ABBRV, dtype: object) Series([], Name: BRN_NM, dtype: object)
# 12 100 8    NH투자증권(우리)
# Name: MKTPARTC_KOR_ABBRV, dtype: object 8    스마트
# Name: BRN_NM, dtype: object
# 2 155 364    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object 364    영업10부
# Name: BRN_NM, dtype: object
# 17 29 4939    현대증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 4939    YF사이버
# Name: BRN_NM, dtype: object
# 42 1 172    CS증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 172    고객
# Name: BRN_NM, dtype: object
# 44 1 282    메릴린치
# Name: MKTPARTC_KOR_ABBRV, dtype: object 282    서울
# Name: BRN_NM, dtype: object
# 2 83 860    신한투자
# Name: MKTPARTC_KOR_ABBRV, dtype: object 860    신한은행
# Name: BRN_NM, dtype: object
# 4 10118 44434    대신증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 44434    다이렉트지점
# Name: BRN_NM, dtype: object
# 4 9997 95    대신증권
# Name: MKTPARTC_KOR_ABBRV, dtype: object 95    은행제휴1
# Name: BRN_NM, dtype: object
# 50 91 Series([], Name: MKTPARTC_KOR_ABBRV, dtype: object) Series([], Name: BRN_NM, dtype: object)

# %%
ISUlist=['KR7215600008', 'KR7068270008', 'KR7028040004', 'KR7065450009',
       'KR7021080007', 'KR7030270003', 'KR7031860000', 'KR7003670007',
       'KR7019550003', 'KR7041140005', 'KR7086520004', 'KR7011320009',
       'KR7091990002', 'KR7078130002', 'KR7134780006', 'KR7192410009',
       'KR7025320003', 'KR7064240005', 'KR7024740003', 'KR7025440009',
       'KR7121800007', 'KR7203650007', 'KR7217270008', 'KR7046120002',
       'KR7224060004', 'KR7178920005', 'KR7036930006', 'KR7200230001',
       'KR7240810002', 'KR7014190003', 'KR7090460007', 'KR7168330009',
       'KR7071670004', 'KR7131100000', 'KR7084990001', 'KR7046890000',
       'KR7193250008', 'KR7049180003', 'KR7022100002', 'KR7208640003',
       'KR7056190002', 'KR7018000000', 'KR7043200005', 'KR7220180004',
       'KR7058530007', 'KR7035900000', 'KR7200710002', 'KR7099830002',
       'KR7080470008', 'KR7066970005', 'KR7037370004', 'KR7106080005',
       'KR7052290004', 'KR7001000009', 'KR7054180005', 'KR7034230003',
       'KR7078650009', 'KR7042040006', 'KR7036630002', 'KR7019570001',
       'KR7078160009', 'KR7097780001', 'KR7108320003', 'KR7078150000',
       'KR7028300002', 'KR7036620003', 'KR7005290002', 'KR7010170009',
       'KR7057680001', 'KR7136480001', 'KR7086900008', 'KR7078340007',
       'KR7215100009', 'KR7095610002', 'KR7052710001', 'KR7031980006',
       'KR7142760008', 'KR7069080000', 'KR7131390007', 'KR7036490001',
       'KR7145020004', 'KR7035620004', 'KR7023900004', 'KR7056730005',
       'KR7215360009', 'KR7082210006', 'KR7130960008', 'KR7220260004',
       'KR7223310004', 'KR7038110003', 'KR7060560000', 'KR7095700001',
       'KR7041510009', 'KR7006910004', 'KR7053110003', 'KR7065350001',
       'KR7094190006', 'KR7051370005', 'KR7225570001', 'KR7204840003']
DDlist=[20170901, 20170904, 20170905, 20170906, 20170907, 20170908,
            20170911, 20170912, 20170913, 20170914, 20170915, 20170918,
            20170919, 20170920, 20170921, 20170922, 20170925, 20170926,
            20170927, 20170928, 20170929]

# %%
data_dir=path_dir+'/'+'ord201709'

UUID_count={}
file_list = os.listdir(data_dir)
print(file_list)
filecount=0
for filename in file_list:
    print(filename)
    if 'ksqord_201709' not in filename:
        continue
    df1 = pd.read_csv(data_dir+'/'+filename, sep=',', header=None, encoding="cp949")
    if 'SPOT' in filename:
        continue
        df1.columns = list(layout_1.iloc[0:len(df1.iloc[0])][0])
        print("Using 2013 data")
    elif 'ksqord_201709' in filename:
        df1.columns= header_df
        df=df[1:]
        print("Using 2017 data")
    else:
        continue
#    df1=df1.set_index(['ORD_DD','ORD_ACPT_TM'])
    for MBR_NO, BRN_NO in mbrnlist:
        if(filecount==0):
            dfmost=df1[(df1['MBR_NO']==MBR_NO) & (df1['BRN_NO']==BRN_NO)&(df1['ISU_CD'].isin(ISUlist))]        
        else:
            dfmost=pd.concat([dfmost,df1[(df1['MBR_NO']==MBR_NO) & (df1['BRN_NO']==BRN_NO)&(df1['ISU_CD'].isin(ISUlist))],])
    #         dfmost.join(df1[(df1['MBR_NO']==max_MBR_NO) & (df1['BRN_NO']==max_BRN_NO)],how='outer')
        filecount+=1
# Out:
# ['ksqord_20170904.csv', 'ksqord_20170905.csv', 'ksqord_20170929.csv', 'ksqord_20170926.csv', 'ksqord_20170913.csv', 'ksqord_20170928.csv', 'ksqord_20170901.csv', 'ksqord_20170918.csv', 'ksqord_20170922.csv', 'ksqord_20170906.csv', 'ksqord_20170919.csv', 'ksqord_20170921.csv', 'ksqord_20170920.csv', 'ksqord_20170925.csv', 'ksqord_20170908.csv', 'ksqord_20170915.csv', 'ksqord_20170907.csv', 'ksqord_20170914.csv', 'ksqord_20170927.csv', 'ksqord_20170911.csv', 'ksqord_20170912.csv']
# ksqord_20170904.csv
# Using 2017 data
# ksqord_20170905.csv
# Using 2017 data
# ksqord_20170929.csv
# Using 2017 data
# ksqord_20170926.csv
# Using 2017 data
# ksqord_20170913.csv
# Using 2017 data
# ksqord_20170928.csv
# Using 2017 data
# ksqord_20170901.csv
# Using 2017 data
# ksqord_20170918.csv
# Using 2017 data
# ksqord_20170922.csv
# Using 2017 data
# ksqord_20170906.csv
# Using 2017 data
# ksqord_20170919.csv
# Using 2017 data
# ksqord_20170921.csv
# Using 2017 data
# ksqord_20170920.csv
# Using 2017 data
# ksqord_20170925.csv
# Using 2017 data
# ksqord_20170908.csv
# Using 2017 data
# ksqord_20170915.csv
# Using 2017 data
# ksqord_20170907.csv
# Using 2017 data
# ksqord_20170914.csv
# Using 2017 data
# ksqord_20170927.csv
# Using 2017 data
# ksqord_20170911.csv
# Using 2017 data
# ksqord_20170912.csv
# Using 2017 data

# %%
dfmostkor = dfmost[dfmost['ISU_CD'].str.contains('KR')]

# %%
dfmostkor.sort_values(by=['ORD_DD','ISU_CD','ORD_ACPT_TM'])
# dfmost.sort_values(by='ORD_DD')
# Out:
#                ISU_CD    ORD_DD  ORD_ACPT_NO  REGUL_OFFHR_TP_CD  BLKTRD_TP_CD  \
# 85433    KR7001000009  20170901            9                  2             0
# 85434    KR7001000009  20170901           10                  2             0
# 85441    KR7001000009  20170901           17                  2             0
# 85445    KR7001000009  20170901           21                  2             0
# 85447    KR7001000009  20170901           23                  2             0
# ...               ...       ...          ...                ...           ...
# 7544742  KR7240810002  20170929           47                  4             0
# 7544754  KR7240810002  20170929           59                  4             0
# 7544759  KR7240810002  20170929           64                  4             0
# 7544760  KR7240810002  20170929           65                  4             0
# 7544773  KR7240810002  20170929           78                  4             0
#
#          호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD ORD_TP_CD  ORD_COND_CD  \
# 85433       3225             2               1         2            0
# 85434       3225             2               1         2            0
# 85441       3225             2               1         2            0
# 85445       3225             2               1         2            0
# 85447       3225             2               1         2            0
# ...          ...           ...             ...       ...          ...
# 7544742    34100             2               1         2            0
# 7544754    34050             2               1         2            0
# 7544759    33800             2               1         2            0
# 7544760    34000             2               1         2            0
# 7544773    34000             2               3         2            0
#
#          INVST_TP_CD  ASK_STEP1_BSTORD_PRC  ASK_STEP1_BSTORD_RQTY  \
# 85433           8000                  3225                   1720
# 85434           8000                  3225                   1690
# 85441           8000                  3225                    459
# 85445           8000                     0                      0
# 85447           8000                     0                      0
# ...              ...                   ...                    ...
# 7544742         8000                 34150                    100
# 7544754         8000                 34150                    150
# 7544759         8000                 34150                     89
# 7544760         8000                 34150                     89
# 7544773         8000                 34150                     59
#
#          ASK_STEP2_BSTORD_PRC  ASK_STEP2_BSTORD_RQTY  ASK_STEP3_BSTORD_PRC  \
# 85433                       0                      0                     0
# 85434                       0                      0                     0
# 85441                       0                      0                     0
# 85445                       0                      0                     0
# 85447                       0                      0                     0
# ...                       ...                    ...                   ...
# 7544742                 34300                      9                 34650
# 7544754                 34300                      9                 34650
# 7544759                 34650                     22                 34800
# 7544760                 34650                     22                 34800
# 7544773                 34500                     19                 34650
#
#          ASK_STEP3_BSTORD_RQTY  ASK_STEP4_BSTORD_PRC  ASK_STEP4_BSTORD_RQTY  \
# 85433                        0                     0                      0
# 85434                        0                     0                      0
# 85441                        0                     0                      0
# 85445                        0                     0                      0
# 85447                        0                     0                      0
# ...                        ...                   ...                    ...
# 7544742                     22                     0                      0
# 7544754                     22                     0                      0
# 7544759                     20                     0                      0
# 7544760                     20                     0                      0
# 7544773                     22                     0                      0
#
#          ASK_STEP5_BSTORD_PRC  ...    회원사주문시각  예상체결가격  예상체결수량  매도총호가잔량  \
# 85433                       0  ...   73726025       0       0     1720
# 85434                       0  ...   73736947       0       0     1690
# 85441                       0  ...   74416235       0       0      459
# 85445                       0  ...   75123829       0       0        0
# 85447                       0  ...   75720709       0       0        0
# ...                       ...  ...        ...     ...     ...      ...
# 7544742                     0  ...  164438842   34100       2     1635
# 7544754                     0  ...  165947973   34000     150     1833
# 7544759                     0  ...  171308619   34150      70     1683
# 7544760                     0  ...  171734090   34150      70     1683
# 7544773                     0  ...  175125240       0       0     1642
#
#          매수총호가잔량  호가체결접수순서번호  직전체결가격  누적체결수량  누적거래대금     AGG_TM  시가     고가  \
# 85433          0          14    3225      30   96750   73726027   0   3225
# 85434          0          16    3225     100  322500   73736948   0   3225
# 85441          0          31    3225     100  322500   74416238   0   3225
# 85445       1153          38    3225       0       0          0   0   3225
# 85447       1230          40    3225       0       0          0   0   3225
# ...          ...         ...     ...     ...     ...        ...  ..    ...
# 7544742      582       24293   34100      10  341000  165030192   0  34100
# 7544754      575       24308   34100       5  170000  170030251   0  34100
# 7544759      737       24318   34000       0       0          0   0  34100
# 7544760      747       24319   34000       0       0          0   0  34100
# 7544773      631       24337   34100       0       0          0   0  34150
#
#             저가  ORGN_ORD_ACPT_NO  시장구분코드  자동취소처리구분코드  MKTSTAT_TP_CD  \
# 85433     3225                 0       2           0             50
# 85434     3225                 0       2           0             50
# 85441     3225                 0       2           0             50
# 85445     3225                 0       2           0             50
# 85447     3225                 0       2           0             50
# ...        ...               ...     ...         ...            ...
# 7544742  34100                 0       2           0             70
# 7544754  34100                 0       2           0             70
# 7544759  34000                 0       2           0             70
# 7544760  34000                 0       2           0             70
# 7544773  34000                65       2           0             70
#
#          매도10단계호가합계잔량  매수10단계호가합계잔량  PT_TP_CD
# 85433            1720             0         0
# 85434            1690             0         0
# 85441             459             0         0
# 85445               0          1153         0
# 85447               0          1230         0
# ...               ...           ...       ...
# 7544742           131           422         0
# 7544754           181           414         0
# 7544759           131           656         0
# 7544760           131           666         0
# 7544773           100           441         0
#
# [10332014 rows x 61 columns]

# %%
groupmin=10
groupsec=0
tottime_ms=(6*3600+1800)*1e3
totgroupnum=tottime_ms/(groupmin*6e4+groupsec*1e3)

# %%
#dfmostkor['hourmin']=dfmostkor['ORD_ACPT_TM']//1000

dfmostkor['ORD_TM']=(dfmostkor['ORD_ACPT_TM']//1e7)*36e5+ ((dfmostkor['ORD_ACPT_TM']%1e7)//1e5)*6e4+(dfmostkor['ORD_ACPT_TM']%1e5)
dfmostkor['ORD_TM']=dfmostkor['ORD_TM']-9*36e5
dfmostkor['time_group']=dfmostkor['ORD_TM']//(groupmin*6e4+groupsec*1e3)
dfmostkor=dfmostkor[(dfmostkor['time_group']>=0) &(dfmostkor['time_group']<40)]

# %% [markdown]
# dfmostkor.groupby(['ISU_CD']).size()

# %% [markdown]
# len(dfmostkor)

# %%
ISU_CD=dfmostkor.groupby(['ISU_CD']).size().idxmax()
print(ISU_CD)
print(dfmostkor.groupby(['ISU_CD']).size().max())
print(dfmostkor.groupby(['ISU_CD']).size().sum())
# Out:
# KR7028040004
# 621760
# 9783425

# %%
dfmostkor.columns
# Out:
# Index(['ISU_CD', 'ORD_DD', 'ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD', 'BLKTRD_TP_CD',
#        '호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 'ORD_COND_CD',
#        'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC', 'ASK_STEP1_BSTORD_RQTY',
#        'ASK_STEP2_BSTORD_PRC', 'ASK_STEP2_BSTORD_RQTY', 'ASK_STEP3_BSTORD_PRC',
#        'ASK_STEP3_BSTORD_RQTY', 'ASK_STEP4_BSTORD_PRC',
#        'ASK_STEP4_BSTORD_RQTY', 'ASK_STEP5_BSTORD_PRC',
#        'ASK_STEP5_BSTORD_RQTY', 'BID_STEP1_BSTORD_PRC',
#        'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC',
#        'BID_STEP2_BSTORD_RQTY', 'BID_STEP3_BSTORD_PRC',
#        'BID_STEP3_BSTORD_RQTY', 'BID_STEP4_BSTORD_PRC',
#        'BID_STEP4_BSTORD_RQTY', 'BID_STEP5_BSTORD_PRC',
#        'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
#        '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD',
#        'FORNINVST_TP_CD', 'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량',
#        '매도총호가잔량', '매수총호가잔량', '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금',
#        'AGG_TM', '시가', '고가', '저가', 'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드',
#        'MKTSTAT_TP_CD', '매도10단계호가합계잔량', '매수10단계호가합계잔량', 'PT_TP_CD', 'ORD_TM',
#        'time_group'],
#       dtype='object')

# %%
#dfISU=dfmostkor[dfmostkor['ISU_CD']==ISU_CD]
dfISU=dfmostkor

# %% [markdown]
# dfISU.columns

# %%
clist=['PT_TP_CD']
dfISU[clist].groupby(clist).size()
# Out:
# PT_TP_CD
# 0     9044059
# 31     739366
# dtype: int64

# %%
columns=['ISU_CD', 'ORD_DD', 'ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD', 'BLKTRD_TP_CD',
       '호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 'ORD_COND_CD',
       'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC', 'ASK_STEP1_BSTORD_RQTY',
       'ASK_STEP2_BSTORD_PRC', 'ASK_STEP2_BSTORD_RQTY', 'ASK_STEP3_BSTORD_PRC',
       'ASK_STEP3_BSTORD_RQTY', 'ASK_STEP4_BSTORD_PRC',
       'ASK_STEP4_BSTORD_RQTY', 'ASK_STEP5_BSTORD_PRC',
       'ASK_STEP5_BSTORD_RQTY', 'BID_STEP1_BSTORD_PRC',
       'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC',
       'BID_STEP2_BSTORD_RQTY', 'BID_STEP3_BSTORD_PRC',
       'BID_STEP3_BSTORD_RQTY', 'BID_STEP4_BSTORD_PRC',
       'BID_STEP4_BSTORD_RQTY', 'BID_STEP5_BSTORD_PRC',
       'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
       '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD',
       'FORNINVST_TP_CD', 'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량',
       '매도총호가잔량', '매수총호가잔량', '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금',
       'AGG_TM', '시가', '고가', '저가', 'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드',
       'MKTSTAT_TP_CD', '매도10단계호가합계잔량', '매수10단계호가합계잔량', 'PT_TP_CD', 'time_group']
columns=['호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 
         'ORD_QTY', 'ORD_PRC', '매도총호가잔량',
       '매수총호가잔량', '직전체결가격', '누적체결수량', '누적거래대금', '시가', '고가', '저가',
        'time_group']
columns= [ '호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 'ORD_COND_CD',
       'INVST_TP_CD', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
        'CNTR_CD', 'FORNINVST_TP_CD', 'ORD_MEDIA_TP_CD', '예상체결가격', '예상체결수량',
       '매도총호가잔량', '매수총호가잔량', '직전체결가격', '누적체결수량', '누적거래대금',
         '시가', '고가', '저가',  'MKTSTAT_TP_CD', 'time_group']
columns= [ '호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_QTY', 'ORD_PRC',
       '매도총호가잔량', '매수총호가잔량', '직전체결가격', 
         '시가', '고가', '저가',  'MKTSTAT_TP_CD', 'time_group']

columns=['ISU_CD','ORD_DD','ASKBID_TP_CD', 'MODCANCL_TP_CD',  'ASK_STEP1_BSTORD_PRC','BID_STEP1_BSTORD_PRC',
         'ORD_QTY', 'ORD_PRC', '매도총호가잔량',
       '매수총호가잔량',  '시가', '고가', '저가','time_group','MBR_NO','BRN_NO']

# %%
columns
# Out:
# ['ISU_CD',
#  'ORD_DD',
#  'ASKBID_TP_CD',
#  'MODCANCL_TP_CD',
#  'ASK_STEP1_BSTORD_PRC',
#  'BID_STEP1_BSTORD_PRC',
#  'ORD_QTY',
#  'ORD_PRC',
#  '매도총호가잔량',
#  '매수총호가잔량',
#  '시가',
#  '고가',
#  '저가',
#  'time_group',
#  'MBR_NO',
#  'BRN_NO']

# %%
Pdf=dfISU[columns]

# %%
dfISU['시가']
# Out:
# 70739       3070
# 71292       3070
# 71325       3070
# 159383      3070
# 159384      3070
#            ...
# 8358027    33200
# 8358028    33200
# 8358094    33200
# 8358095    33200
# 8358096    33200
# Name: 시가, Length: 9783425, dtype: int64

# %%
Pdf=Pdf[Pdf['ORD_PRC']!=0]
Pdf=Pdf[Pdf['MODCANCL_TP_CD']==1]
Pdf['시가']=(Pdf['ASK_STEP1_BSTORD_PRC']+Pdf['BID_STEP1_BSTORD_PRC'])/2
Pdf['count']=1
Pdf['High']=(Pdf['고가']-Pdf['시가'])/Pdf['시가']
Pdf['Low']=(Pdf['저가']-Pdf['시가'])/Pdf['시가']
Pdf['ORD_NET']=Pdf['ORD_PRC']*Pdf['ORD_QTY']
PdfA=Pdf[Pdf['ASKBID_TP_CD']==1]
PdfB=Pdf[Pdf['ASKBID_TP_CD']==2]

# %%
newcolumns=['ISU_CD','ORD_DD','time_group','MBR_NO','BRN_NO','시가','ORD_QTY','ORD_NET',  'High','Low','매도총호가잔량',
       '매수총호가잔량','count']
PdfA=PdfA[newcolumns]
PdfB=PdfB[newcolumns]

# %%
PdfAA=PdfA.groupby(['ISU_CD','ORD_DD','time_group','MBR_NO','BRN_NO']).sum()
#PdfAA['시가','High','Low','매도호가잔량','매수호가잔량']=PdfAA['시가','High','Low','매도호가잔량','매수호가잔량']/PdfAA['count']
PdfAA['시가']=PdfAA['시가']/PdfAA['count']
PdfAA['High']=PdfAA['High']/PdfAA['count']
PdfAA['Low']=PdfAA['Low']/PdfAA['count']
PdfAA['매도총호가잔량']=PdfAA['매도총호가잔량']/PdfAA['count']
PdfAA['매수총호가잔량']=PdfAA['매수총호가잔량']/PdfAA['count']
PdfAA['ORD_PRC_REL']=PdfAA['ORD_NET']/PdfAA['ORD_QTY']/PdfAA['시가']
PdfBB=PdfB.groupby(['ISU_CD','ORD_DD','time_group']).sum()
#PdfAA['시가','High','Low','매도호가잔량','매수호가잔량']=PdfAA['시가','High','Low','매도호가잔량','매수호가잔량']/PdfAA['count']
PdfBB['시가']=PdfBB['시가']/PdfBB['count']
PdfBB['High']=PdfBB['High']/PdfBB['count']
PdfBB['Low']=PdfBB['Low']/PdfBB['count']
PdfBB['매도총호가잔량']=PdfBB['매도총호가잔량']/PdfBB['count']
PdfBB['매수총호가잔량']=PdfBB['매수총호가잔량']/PdfBB['count']
PdfBB['ORD_PRC_REL']=PdfBB['ORD_NET']/PdfBB['ORD_QTY']/PdfBB['시가']

# %%
dfmostkor
# Out:
#                ISU_CD    ORD_DD  ORD_ACPT_NO  REGUL_OFFHR_TP_CD  BLKTRD_TP_CD  \
# 70739    KR7001000009  20170904         1670                  1             0
# 71292    KR7001000009  20170904         2225                  1             0
# 71325    KR7001000009  20170904         2258                  1             0
# 159383   KR7001000009  20170904        90296                  1             0
# 159384   KR7001000009  20170904   1000090296                  1             0
# ...               ...       ...          ...                ...           ...
# 8358027  KR7240810002  20170912        35804                  1             0
# 8358028  KR7240810002  20170912        35805                  1             0
# 8358094  KR7240810002  20170912        35871                  1             0
# 8358095  KR7240810002  20170912        35872                  1             0
# 8358096  KR7240810002  20170912        35873                  1             0
#
#          호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD ORD_TP_CD  ORD_COND_CD  \
# 70739       3140             1               1         2            0
# 71292       3215             1               1         2            0
# 71325       3225             1               1         2            0
# 159383      3190             2               1         2            3
# 159384      3190             2               3         2            3
# ...          ...           ...             ...       ...          ...
# 8358027    33300             1               1         2            0
# 8358028    33450             1               1         2            0
# 8358094    33250             1               1         2            0
# 8358095    33350             1               1         2            0
# 8358096    33300             1               1         2            0
#
#          INVST_TP_CD  ASK_STEP1_BSTORD_PRC  ASK_STEP1_BSTORD_RQTY  \
# 70739           1000                  3145                    500
# 71292           1000                  3215                    459
# 71325           1000                  3225                    322
# 159383          5000                  3190                   2409
# 159384          5000                  3195                     70
# ...              ...                   ...                    ...
# 8358027         7100                 33450                     84
# 8358028         7100                 33450                    345
# 8358094         7100                 33350                    672
# 8358095         7100                 33350                    717
# 8358096         7100                 33350                    770
#
#          ASK_STEP2_BSTORD_PRC  ASK_STEP2_BSTORD_RQTY  ASK_STEP3_BSTORD_PRC  \
# 70739                    3150                    624                  3155
# 71292                    3220                   1427                  3225
# 71325                    3230                   6834                  3235
# 159383                   3195                     70                  3200
# 159384                   3200                   2072                  3205
# ...                       ...                    ...                   ...
# 8358027                 33500                   2496                 33550
# 8358028                 33500                   2496                 33550
# 8358094                 33400                   1723                 33450
# 8358095                 33400                   1723                 33450
# 8358096                 33400                   1723                 33450
#
#          ASK_STEP3_BSTORD_RQTY  ASK_STEP4_BSTORD_PRC  ASK_STEP4_BSTORD_RQTY  \
# 70739                      598                  3160                   6422
# 71292                      150                  3230                  10160
# 71325                       84                  3240                   4654
# 159383                    2072                  3205                   1199
# 159384                    1199                  3210                   1077
# ...                        ...                   ...                    ...
# 8358027                   7289                     0                      0
# 8358028                   7289                     0                      0
# 8358094                    981                     0                      0
# 8358095                    981                     0                      0
# 8358096                    981                     0                      0
#
#          ASK_STEP5_BSTORD_PRC  ...  예상체결수량  매도총호가잔량  매수총호가잔량  호가체결접수순서번호  \
# 70739                    3165  ...       0   371691   108121        2148
# 71292                    3235  ...       0   391555   126987        2993
# 71325                    3245  ...       0   386080   115199        3058
# 159383                   3210  ...       0   851217   159447      158907
# 159384                   3215  ...       0   848808   159447      158909
# ...                       ...  ...     ...      ...      ...         ...
# 8358027                     0  ...   13427   199166    52490       51231
# 8358028                     0  ...   13427   199427    52490       51232
# 8358094                     0  ...   15152   203679    54075       51298
# 8358095                     0  ...   15152   203724    54075       51299
# 8358096                     0  ...   15152   203777    54075       51300
#
#          직전체결가격  누적체결수량    누적거래대금     AGG_TM     시가     고가     저가  \
# 70739      3140    1403   4405420   90502192   3070   3150   3050
# 71292      3220     459   1475685   90828328   3070   3220   3050
# 71325      3215     322   1038450   90830876   3070   3230   3050
# 159383     3190    2409   7684710  144452420   3070   3480   3050
# 159384     3190       0         0          0   3070   3480   3050
# ...         ...     ...       ...        ...    ...    ...    ...
# 8358027   33200     354  11805900  153013995  33200  33900  32650
# 8358028   33200       0         0          0  33200  33900  32650
# 8358094   33200     142   4735700  153013995  33200  33900  32650
# 8358095   33200       0         0          0  33200  33900  32650
# 8358096   33200      53   1767550  153013995  33200  33900  32650
#
#          ORGN_ORD_ACPT_NO  시장구분코드  자동취소처리구분코드  MKTSTAT_TP_CD  매도10단계호가합계잔량  \
# 70739                   0       2           0             40         10746
# 71292                   0       2           0             40         19260
# 71325                   0       2           0             40         13792
# 159383                  0       2           0             40         40904
# 159384              90296       2           1             40         40855
# ...                   ...     ...         ...            ...           ...
# 8358027                 0       2           0             30          9869
# 8358028                 0       2           0             30         10130
# 8358094                 0       2           0             30          3376
# 8358095                 0       2           0             30          3421
# 8358096                 0       2           0             30          3474
#
#          매수10단계호가합계잔량  PT_TP_CD      ORD_TM  time_group
# 70739           16723         0    302192.0         0.0
# 71292           15459         0    506294.0         0.0
# 71325           12341         0    510177.0         0.0
# 159383          78215         0  20692420.0        34.0
# 159384          78215         0  20692420.0        34.0
# ...               ...       ...         ...         ...
# 8358027           172        31  23129711.0        38.0
# 8358028           172        31  23129713.0        38.0
# 8358094           564        31  23380440.0        38.0
# 8358095           564        31  23380441.0        38.0
# 8358096           564        31  23380445.0        38.0
#
# [9783425 rows x 63 columns]

# %%
PdfAA.add(-1*PdfBB,fill_value=0)
# Out:
#                                                  BRN_NO      High       Low  \
# ISU_CD       ORD_DD   time_group MBR_NO BRN_NO
# KR7001000009 20170901 0.0        2      83     -99150.0  0.000890 -0.000313
#                                  4      9997   -99150.0 -0.000629 -0.004839
#                                         10118  -99150.0 -0.001632  0.002949
#                                  5      194    -99150.0 -0.000531 -0.000402
#                                  8      298    -99150.0 -0.003378 -0.002022
# ...                                                 ...       ...       ...
# KR7240810002 20170929 37.0       44     1      -32273.0  0.000229  0.000220
#                                  50     92     -32273.0  0.000229  0.000220
#                       38.0       4      9997     -948.0  0.003665  0.003530
#                                  5      194      -948.0  0.003665  0.003530
#                                  42     1        -948.0  0.001393  0.001342
#
#                                                 MBR_NO      ORD_NET  \
# ISU_CD       ORD_DD   time_group MBR_NO BRN_NO
# KR7001000009 20170901 0.0        2      83     -1116.0  -55547840.0
#                                  4      9997   -1116.0 -103360995.0
#                                         10118  -1116.0 -100645110.0
#                                  5      194    -1116.0  -85162290.0
#                                  8      298    -1116.0  -91590965.0
# ...                                                ...          ...
# KR7240810002 20170929 37.0       44     1       -322.0 -126076100.0
#                                  50     92      -322.0 -134224800.0
#                       38.0       4      9997    -177.0   -8808150.0
#                                  5      194     -177.0  -15444250.0
#                                  42     1       -177.0   20186350.0
#
#                                                 ORD_PRC_REL  ORD_QTY  count  \
# ISU_CD       ORD_DD   time_group MBR_NO BRN_NO
# KR7001000009 20170901 0.0        2      83         0.019002 -17746.0  -64.0
#                                  4      9997       0.085601 -32524.0  -65.0
#                                         10118      0.080532 -31731.0  -64.0
#                                  5      194        0.057030 -27106.0  -61.0
#                                  8      298        0.017309 -28865.0  -60.0
# ...                                                     ...      ...    ...
# KR7240810002 20170929 37.0       44     1         -0.000801  -3709.0  -14.0
#                                  50     92         0.006411  -3949.0  -18.0
#                       38.0       4      9997       0.000280   -258.0   -6.0
#                                  5      194        0.032562   -457.0   -6.0
#                                  42     1          0.006154    588.0   -5.0
#
#                                                      매도총호가잔량       매수총호가잔량  \
# ISU_CD       ORD_DD   time_group MBR_NO BRN_NO
# KR7001000009 20170901 0.0        2      83      19899.661765   -123.000000
#                                  4      9997    18183.078431  13843.083333
#                                         10118  -25832.838235 -11141.500000
#                                  5      194     -2489.873950  -2432.107143
#                                  8      298    -21189.963235  -4150.250000
# ...                                                      ...           ...
# KR7240810002 20170929 37.0       44     1        1222.116667  -5244.550000
#                                  50     92      -2178.050000    760.450000
#                       38.0       4      9997     3494.857143   2175.428571
#                                  5      194      -116.142857   -501.571429
#                                  42     1        2689.857143   2104.928571
#
#                                                         시가
# ISU_CD       ORD_DD   time_group MBR_NO BRN_NO
# KR7001000009 20170901 0.0        2      83       -0.588235
#                                  4      9997     14.203431
#                                         10118     1.286765
#                                  5      194       1.822479
#                                  8      298      10.036765
# ...                                                    ...
# KR7240810002 20170929 37.0       44     1        -7.500000
#                                  50     92       -7.500000
#                       38.0       4      9997   -121.428571
#                                  5      194    -121.428571
#                                  42     1       -46.428571
#
# [434485 rows x 11 columns]

# %%
Y=PdfAA.add(-1*PdfBB,fill_value=0)['ORD_QTY']

# %% [markdown]
# ISU_CD_list=(X.groupby(['ISU_CD']).count().reset_index())['ISU_CD'].to_list()

# %%
Y=Y.reset_index()
Y=Y[Y['ISU_CD'].isin(ISUlist)]
Y=Y.set_index(['ISU_CD','ORD_DD','time_group'])

# %%
timedf_columns=['ISU_CD', 'ORD_DD', 'time_group', 'ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD',
       'BLKTRD_TP_CD', '호가장처리가격', 'ASKBID_TP_CD', 'MODCANCL_TP_CD',
       'ORD_TP_CD', 'ORD_COND_CD', 'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC',
       'ASK_STEP1_BSTORD_RQTY', 'ASK_STEP2_BSTORD_PRC',
       'ASK_STEP2_BSTORD_RQTY', 'ASK_STEP3_BSTORD_PRC',
       'ASK_STEP3_BSTORD_RQTY', 'ASK_STEP4_BSTORD_PRC',
       'ASK_STEP4_BSTORD_RQTY', 'ASK_STEP5_BSTORD_PRC',
       'ASK_STEP5_BSTORD_RQTY', 'BID_STEP1_BSTORD_PRC',
       'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC',
       'BID_STEP2_BSTORD_RQTY', 'BID_STEP3_BSTORD_PRC',
       'BID_STEP3_BSTORD_RQTY', 'BID_STEP4_BSTORD_PRC',
       'BID_STEP4_BSTORD_RQTY', 'BID_STEP5_BSTORD_PRC',
       'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
       '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD',
       'FORNINVST_TP_CD', 'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량',
       '매도총호가잔량', '매수총호가잔량', '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금',
       'AGG_TM', '시가', '고가', '저가', 'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드',
       'MKTSTAT_TP_CD', '매도10단계호가합계잔량', '매수10단계호가합계잔량', 'PT_TP_CD', 'ORD_TM']

# %%
from numpy import load
timedf_load_data=load('Data0930_'+str(groupmin)+'min'+'.npy',allow_pickle=True)
timedf_load = pd.DataFrame(timedf_load_data,columns=timedf_columns)

# %%
timedf_load
# Out:
#              ISU_CD    ORD_DD time_group ORD_ACPT_NO REGUL_OFFHR_TP_CD  \
# 0      KR7215600008  20170901          0     13834.0               1.0
# 1      KR7215600008  20170901          1     19814.0               1.0
# 2      KR7215600008  20170901          2     23536.0               1.0
# 3      KR7215600008  20170901          3     26384.0               1.0
# 4      KR7215600008  20170901          4     31874.0               1.0
# ...             ...       ...        ...         ...               ...
# 81895  KR7204840003  20170929         34    100156.0               1.0
# 81896  KR7204840003  20170929         35    101574.0               1.0
# 81897  KR7204840003  20170929         36    102727.0               1.0
# 81898  KR7204840003  20170929         37    105329.0               1.0
# 81899  KR7204840003  20170929         38    106647.0               1.0
#
#       BLKTRD_TP_CD  호가장처리가격 ASKBID_TP_CD MODCANCL_TP_CD ORD_TP_CD ORD_COND_CD  \
# 0              0.0  26300.0          1.0            1.0         2         0.0
# 1              0.0  25700.0          2.0            2.0         2         0.0
# 2              0.0  25900.0          2.0            1.0         2         0.0
# 3              0.0  26250.0          1.0            2.0         2         0.0
# 4              0.0  26850.0          2.0            1.0         2         0.0
# ...            ...      ...          ...            ...       ...         ...
# 81895          0.0   3625.0          1.0            1.0         2         0.0
# 81896          0.0   3660.0          1.0            2.0         2         0.0
# 81897          0.0   3660.0          1.0            2.0         2         0.0
# 81898          0.0   3605.0          2.0            1.0         2         0.0
# 81899          0.0   3670.0          2.0            1.0         2         0.0
#
#       INVST_TP_CD ASK_STEP1_BSTORD_PRC ASK_STEP1_BSTORD_RQTY  \
# 0          8000.0              26300.0                 483.0
# 1          8000.0              26200.0                1736.0
# 2          8000.0              25950.0                3919.0
# 3          8000.0              26250.0                7577.0
# 4          8000.0              26900.0                1986.0
# ...           ...                  ...                   ...
# 81895      8000.0               3630.0                 710.0
# 81896      8000.0               3670.0                6111.0
# 81897      8000.0               3635.0                 438.0
# 81898      8000.0               3630.0                 645.0
# 81899      8000.0               3625.0                3587.0
#
#       ASK_STEP2_BSTORD_PRC ASK_STEP2_BSTORD_RQTY ASK_STEP3_BSTORD_PRC  \
# 0                  26350.0               17396.0              26400.0
# 1                  26250.0                7530.0              26300.0
# 2                  26000.0               15397.0              26050.0
# 3                  26300.0               18055.0              26350.0
# 4                  26950.0               20139.0              27000.0
# ...                    ...                   ...                  ...
# 81895               3635.0                1110.0               3640.0
# 81896               3675.0               32471.0               3680.0
# 81897               3640.0                2466.0               3645.0
# 81898               3635.0                2295.0               3640.0
# 81899               3630.0               12572.0               3635.0
#
#       ASK_STEP3_BSTORD_RQTY ASK_STEP4_BSTORD_PRC ASK_STEP4_BSTORD_RQTY  ...  \
# 0                    7350.0              26450.0                8122.0  ...
# 1                   16453.0              26350.0                5045.0  ...
# 2                    2939.0              26100.0               11251.0  ...
# 3                   10558.0              26400.0               18892.0  ...
# 4                  113176.0              27050.0                7499.0  ...
# ...                     ...                  ...                   ...  ...
# 81895                2567.0               3645.0                2928.0  ...
# 81896                2384.0               3685.0                5490.0  ...
# 81897                3982.0               3650.0                4548.0  ...
# 81898                8146.0               3645.0               12742.0  ...
# 81899                2880.0                  0.0                   0.0  ...
#
#        예상체결가격    예상체결수량    매도총호가잔량   매수총호가잔량 호가체결접수순서번호   직전체결가격 누적체결수량  \
# 0         0.0       0.0   398157.0  184609.0    21224.0  26200.0    1.0
# 1         0.0       0.0   627758.0  229369.0    30265.0  26200.0    0.0
# 2         0.0       0.0   738502.0  231793.0    36073.0  25900.0   10.0
# 3         0.0       0.0   754454.0  269997.0    40289.0  26200.0  100.0
# 4         0.0       0.0   518296.0  322407.0    49887.0  26850.0    0.0
# ...       ...       ...        ...       ...        ...      ...    ...
# 81895     0.0       0.0  1580347.0  723070.0   159248.0   3625.0  100.0
# 81896     0.0       0.0  1564255.0  622605.0   161497.0   3660.0  509.0
# 81897     0.0       0.0  1549084.0  682581.0   163192.0   3635.0    0.0
# 81898     0.0       0.0  1475171.0  623221.0   167718.0   3630.0    0.0
# 81899  3620.0  197210.0  1604389.0  755081.0   169036.0   3630.0    0.0
#
#           누적거래대금       AGG_TM       시가       고가       저가 ORGN_ORD_ACPT_NO  \
# 0        26300.0   91013989.0  25800.0  26550.0  25550.0              0.0
# 1            0.0          0.0  25800.0  26550.0  25550.0          19763.0
# 2       259000.0   93010117.0  25800.0  26550.0  25550.0              0.0
# 3      2625000.0   94222582.0  25800.0  26550.0  25550.0          20185.0
# 4            0.0          0.0  25800.0  26950.0  25550.0              0.0
# ...          ...          ...      ...      ...      ...              ...
# 81895   362500.0  144959443.0   3800.0   4175.0   3555.0              0.0
# 81896  1862940.0  145959364.0   3800.0   4175.0   3555.0          99322.0
# 81897        0.0          0.0   3800.0   4175.0   3555.0         102685.0
# 81898        0.0          0.0   3800.0   4175.0   3555.0              0.0
# 81899        0.0          0.0   3800.0   4175.0   3555.0              0.0
#
#       시장구분코드 자동취소처리구분코드 MKTSTAT_TP_CD 매도10단계호가합계잔량 매수10단계호가합계잔량 PT_TP_CD  \
# 0        2.0        0.0          40.0      87545.0      47372.0      0.0
# 1        2.0        0.0          40.0     145392.0      70994.0      0.0
# 2        2.0        0.0          40.0      98347.0      91888.0      0.0
# 3        2.0        0.0          40.0     213187.0      76127.0      0.0
# 4        2.0        0.0          40.0     213106.0      66573.0      0.0
# ...      ...        ...           ...          ...          ...      ...
# 81895    2.0        0.0          40.0      53621.0     103401.0      0.0
# 81896    2.0        0.0          40.0     108089.0      35223.0      0.0
# 81897    2.0        0.0          40.0      52778.0     124879.0      0.0
# 81898    2.0        0.0          40.0      60998.0      98915.0      0.0
# 81899    2.0        0.0          30.0      19039.0      44272.0      0.0
#
#            ORD_TM
# 0        599881.0
# 1       1199761.0
# 2       1799790.0
# 3       2399947.0
# 4       2999878.0
# ...           ...
# 81895  20999443.0
# 81896  21599364.0
# 81897  22198826.0
# 81898  22799618.0
# 81899  23399895.0
#
# [81900 rows x 63 columns]

# %%
timedf_load['High']=(timedf_load['고가']-timedf_load['시가'])/timedf_load['시가']
timedf_load['Low']=(timedf_load['저가']-timedf_load['시가'])/timedf_load['시가']
timedf_load['현재가']=(timedf_load['ASK_STEP1_BSTORD_PRC']+timedf_load['BID_STEP1_BSTORD_PRC'])/2
timedf_load['Present']=(timedf_load['현재가']-timedf_load['시가'])/timedf_load['시가']

# %%
timedf_load[['매수총호가잔량']].mean(axis=0)
# Out:
# 매수총호가잔량    238337.597875
# dtype: float64

# %%
Y
# Out:
#                                   MBR_NO   BRN_NO  ORD_QTY
# ISU_CD       ORD_DD   time_group
# KR7001000009 20170901 0.0            2.0     83.0 -17746.0
#                       0.0            4.0   9997.0 -32524.0
#                       0.0            4.0  10118.0 -31731.0
#                       0.0            5.0    194.0 -27106.0
#                       0.0            8.0    298.0 -28865.0
# ...                                  ...      ...      ...
# KR7240810002 20170929 37.0          44.0      1.0  -3709.0
#                       37.0          50.0     92.0  -3949.0
#                       38.0           4.0   9997.0   -258.0
#                       38.0           5.0    194.0   -457.0
#                       38.0          42.0      1.0    588.0
#
# [434485 rows x 3 columns]

# %%
Feature_norm=True

for MBR_NO, BRN_NO in mbrnlist:
    timedf= timedf_load.set_index(['ISU_CD','ORD_DD','time_group'])
    timedf['ORD_QTY']=Y[(Y['MBR_NO']==MBR_NO) & (Y['BRN_NO']==BRN_NO)]['ORD_QTY']
    timedf['ORD_QTY']=timedf['ORD_QTY'].fillna(0)
    Data=timedf[[   '시가','매도총호가잔량',       '매수총호가잔량',  'Present', 'High', 'Low','ORD_QTY']]
    save('Data0930_'+str(MBR_NO)+'_'+str(BRN_NO)+'.npy', Data)
    Data_index=Data.reset_index()

    Data_train=Data_index[Data_index['ORD_DD']<20170928]
    Data_train=Data_train.set_index(['ISU_CD','ORD_DD','time_group'])
    
    if Feature_norm:
        rem_avg=Data_train[['매수총호가잔량']].mean(axis=0)[0]+Data_train[['매도총호가잔량']].mean(axis=0)[0]
        Data_train[['매도총호가잔량','매수총호가잔량']]=Data_train[['매도총호가잔량','매수총호가잔량']]/rem_avg
        
    Data_test=Data_index[Data_index['ORD_DD']>20170927]
    Data_test=Data_test.set_index(['ISU_CD','ORD_DD','time_group'])
    if Feature_norm:
        Data_test[['매도총호가잔량','매수총호가잔량']]=Data_test[['매도총호가잔량','매수총호가잔량']]/rem_avg
        
    if Feature_norm:
        save('Data0930_'+str(MBR_NO)+'_'+str(BRN_NO)+'norm_train'+'.npy', Data_train)
        save('Data0930_'+str(MBR_NO)+'_'+str(BRN_NO)+'norm_test'+'.npy', Data_test)
    else:
        save('Data0930_'+str(MBR_NO)+'_'+str(BRN_NO)+'_train'+'.npy', Data_train)
        save('Data0930_'+str(MBR_NO)+'_'+str(BRN_NO)+'_test'+'.npy', Data_test)

# %%
Data_test.head(100)
# Out:
#                                         시가   매도총호가잔량   매수총호가잔량   Present  \
# ISU_CD       ORD_DD   time_group
# KR7215600008 20170928 0            43800.0  0.585724  0.523705 -0.013128
#                       1            43800.0  0.699016  0.567348 -0.000571
#                       2            43800.0  0.766776   0.59813  0.001712
#                       3            43800.0  0.811111  0.623398 -0.002854
#                       4            43800.0  0.840769  0.639045 -0.005137
#                       5            43800.0  0.884364  0.628463 -0.005137
#                       6            43800.0   0.90941  0.638572 -0.006279
#                       7            43800.0  0.927686  0.631243 -0.011986
#                       8            43800.0  0.943313  0.649216 -0.013128
#                       9            43800.0   0.94438  0.680517 -0.003995
#                       10           43800.0  0.961717  0.672508 -0.010845
#                       11           43800.0  0.973096  0.675597 -0.011986
#                       12           43800.0  0.997416  0.682214 -0.011986
#                       13           43800.0  1.007235  0.687696 -0.011986
#                       14           43800.0  1.016893  0.654737 -0.015411
#                       15           43800.0  1.018578  0.633699 -0.013128
#                       16           43800.0   1.03195  0.686885 -0.017694
#                       17           43800.0  1.025477  0.696425 -0.015411
#                       18           43800.0  1.017702  0.702868 -0.009703
#                       19           43800.0  1.029787  0.695961 -0.005137
#                       20           43800.0  1.049606  0.696946 -0.006279
#                       21           43800.0  1.049407  0.698424 -0.001712
#                       22           43800.0  1.042506  0.701294  0.000571
#                       23           43800.0  1.046218  0.701447  0.006279
#                       24           43800.0  1.059149  0.676633  0.000571
#                       25           43800.0  1.072704  0.676841  0.001142
#                       26           43800.0  1.056142  0.679744   0.00742
#                       27           43800.0  1.079647  0.682917  0.008562
#                       28           43800.0  1.086975  0.682047  0.001712
#                       29           43800.0  1.099419  0.680874  0.002854
#                       30           43800.0  1.103966  0.672257 -0.001712
#                       31           43800.0  1.106063  0.668047 -0.002854
#                       32           43800.0  1.119784  0.668041 -0.006279
#                       33           43800.0  1.116342  0.647804  -0.00742
#                       34           43800.0   1.10233   0.66722 -0.001712
#                       35           43800.0  1.092812  0.653879 -0.003995
#                       36           43800.0  1.080357  0.675876 -0.009703
#                       37           43800.0  1.072602  0.625844 -0.018836
#                       38           43800.0   1.09423  0.616548 -0.019977
#              20170929 0            43400.0  0.562631  0.399462  0.000576
#                       1            43400.0  0.631996  0.427789 -0.006336
#                       2            43400.0   0.67278  0.435043  0.001728
#                       3            43400.0  0.686447  0.460495  0.009793
#                       4            43400.0  0.756128  0.460987   0.00288
#                       5            43400.0  0.784632  0.477755  0.004032
#                       6            43400.0  0.801281  0.475715   0.00288
#                       7            43400.0  0.737784  0.520804   0.03629
#                       8            43400.0  0.911659  0.531835  0.032834
#                       9            43400.0  0.974465  0.559982  0.040899
#                       10           43400.0  1.111807  0.544807  0.031682
#                       11           43400.0  1.090447   0.57215  0.039747
#                       12           43400.0  1.123068  0.584864  0.039747
#                       13           43400.0  1.144623  0.586219  0.037442
#                       14           43400.0  1.188019  0.605755   0.03629
#                       15           43400.0  1.024621  0.587785  0.070853
#                       16           43400.0  1.188587  0.619228  0.067396
#                       17           43400.0  1.291249  0.571185  0.055876
#                       18           43400.0  1.327618  0.587532  0.054724
#                       19           43400.0  1.377962   0.58141  0.046659
#                       20           43400.0  1.426726  0.591026  0.052419
#                       21           43400.0  1.453757  0.592298  0.050691
#                       22           43400.0  1.463899  0.561576  0.039747
#                       23           43400.0  1.493487  0.563741  0.032834
#                       24           43400.0  1.490133  0.533956  0.029378
#                       25           43400.0  1.493968  0.528458  0.029378
#                       26           43400.0  1.514233  0.549816  0.028226
#                       27           43400.0  1.490331  0.545185  0.033986
#                       28           43400.0  1.492631  0.543438  0.037442
#                       29           43400.0  1.491056  0.537498  0.040323
#                       30           43400.0  1.506016  0.538516  0.035138
#                       31           43400.0  1.494348  0.578087  0.042051
#                       32           43400.0  1.507062  0.561392  0.038594
#                       33           43400.0  1.504855  0.529513  0.029378
#                       34           43400.0  1.499072  0.588371  0.025922
#                       35           43400.0  1.495415  0.584936  0.035138
#                       36           43400.0  1.469978  0.575322  0.023618
#                       37           43400.0  1.451415  0.575417  0.025922
#                       38           43400.0  1.476953  0.673933  0.029378
# KR7068270008 20170928 0           149700.0  0.573359  0.075391 -0.016366
#                       1           149700.0  0.656212   0.11388  -0.01837
#                       2           149700.0  0.657476   0.13079 -0.014362
#                       3           149700.0   0.67446  0.132761  -0.00835
#                       4           149700.0  0.716036  0.137696  -0.00835
#                       5           149700.0  0.730385  0.135529 -0.011022
#                       6           149700.0  0.739717  0.140965 -0.007682
#                       7           149700.0  0.758651  0.154468 -0.010354
#                       8           149700.0  0.778112  0.153668 -0.012358
#                       9           149700.0  0.782475  0.159099 -0.011022
#                       10          149700.0  0.817357  0.147329 -0.014362
#                       11          149700.0  0.830965  0.157166 -0.013694
#                       12          149700.0  0.847168   0.14907 -0.017702
#                       13          149700.0  0.853462  0.142461 -0.019706
#                       14          149700.0    0.8498  0.122282 -0.022378
#                       15          149700.0  0.852808  0.131526 -0.019038
#                       16          149700.0  0.858576  0.132771  -0.01837
#                       17          149700.0  0.861104  0.134634  -0.01837
#                       18          149700.0  0.877244  0.136879 -0.019038
#                       19          149700.0  0.880528   0.14195  -0.01837
#                       20          149700.0  0.882547  0.144639  -0.01837
#                       21          149700.0  0.887423  0.143384 -0.017034
#
#                                       High       Low   ORD_QTY
# ISU_CD       ORD_DD   time_group
# KR7215600008 20170928 0           0.004566 -0.020548       0.0
#                       1           0.005708 -0.020548       0.0
#                       2           0.012557 -0.020548       0.0
#                       3           0.012557 -0.020548       0.0
#                       4           0.012557 -0.020548       0.0
#                       5           0.012557 -0.020548       0.0
#                       6           0.012557 -0.020548       0.0
#                       7           0.012557 -0.020548       0.0
#                       8           0.012557 -0.020548       0.0
#                       9           0.012557 -0.020548       0.0
#                       10          0.012557 -0.020548       0.0
#                       11          0.012557 -0.020548       0.0
#                       12          0.012557 -0.020548       0.0
#                       13          0.012557 -0.020548       0.0
#                       14          0.012557 -0.020548       0.0
#                       15          0.012557 -0.020548       0.0
#                       16          0.012557 -0.020548       0.0
#                       17          0.012557 -0.020548       0.0
#                       18          0.012557 -0.020548       0.0
#                       19          0.012557 -0.020548       0.0
#                       20          0.012557 -0.020548       0.0
#                       21          0.012557 -0.020548       0.0
#                       22          0.012557 -0.020548       0.0
#                       23          0.012557 -0.020548       0.0
#                       24          0.012557 -0.020548       0.0
#                       25          0.012557 -0.020548       0.0
#                       26           0.01484 -0.020548       0.0
#                       27           0.01484 -0.020548       0.0
#                       28           0.01484 -0.020548       0.0
#                       29           0.01484 -0.020548       0.0
#                       30           0.01484 -0.020548       0.0
#                       31           0.01484 -0.020548       0.0
#                       32           0.01484 -0.020548       0.0
#                       33           0.01484 -0.020548       0.0
#                       34           0.01484 -0.020548       0.0
#                       35           0.01484 -0.020548       0.0
#                       36           0.01484 -0.020548       0.0
#                       37           0.01484 -0.020548       0.0
#                       38           0.01484 -0.020548       0.0
#              20170929 0           0.006912  -0.00576       0.0
#                       1           0.006912 -0.008065       0.0
#                       2           0.006912 -0.008065       0.0
#                       3           0.014977 -0.008065       0.0
#                       4           0.014977 -0.008065       0.0
#                       5           0.014977 -0.008065       0.0
#                       6           0.014977 -0.008065       0.0
#                       7           0.040323 -0.008065       0.0
#                       8           0.049539 -0.008065       0.0
#                       9           0.049539 -0.008065       0.0
#                       10          0.049539 -0.008065       0.0
#                       11          0.049539 -0.008065       0.0
#                       12          0.049539 -0.008065       0.0
#                       13          0.049539 -0.008065       0.0
#                       14          0.049539 -0.008065  -22788.0
#                       15          0.073733 -0.008065 -103019.0
#                       16          0.073733 -0.008065       0.0
#                       17          0.077189 -0.008065       0.0
#                       18          0.077189 -0.008065       0.0
#                       19          0.077189 -0.008065       0.0
#                       20          0.077189 -0.008065   17648.0
#                       21          0.077189 -0.008065     513.0
#                       22          0.077189 -0.008065       0.0
#                       23          0.077189 -0.008065   34233.0
#                       24          0.077189 -0.008065   21235.0
#                       25          0.077189 -0.008065  -13617.0
#                       26          0.077189 -0.008065       0.0
#                       27          0.077189 -0.008065       0.0
#                       28          0.077189 -0.008065       0.0
#                       29          0.077189 -0.008065       0.0
#                       30          0.077189 -0.008065       0.0
#                       31          0.077189 -0.008065       0.0
#                       32          0.077189 -0.008065       0.0
#                       33          0.077189 -0.008065       0.0
#                       34          0.077189 -0.008065       0.0
#                       35          0.077189 -0.008065       0.0
#                       36          0.077189 -0.008065       0.0
#                       37          0.077189 -0.008065       0.0
#                       38          0.077189 -0.008065       0.0
# KR7068270008 20170928 0                0.0 -0.024716  -18738.0
#                       1                0.0 -0.024716  -17713.0
#                       2                0.0 -0.024716    6507.0
#                       3                0.0 -0.024716   39324.0
#                       4                0.0 -0.024716     481.0
#                       5                0.0 -0.024716   -5531.0
#                       6                0.0 -0.024716   -4495.0
#                       7                0.0 -0.024716   -3479.0
#                       8                0.0 -0.024716   -3514.0
#                       9                0.0 -0.024716   -6614.0
#                       10               0.0 -0.024716   -2544.0
#                       11               0.0 -0.024716   -2309.0
#                       12               0.0 -0.024716   -2339.0
#                       13               0.0 -0.024716   -3340.0
#                       14               0.0 -0.024716    3815.0
#                       15               0.0 -0.024716   12930.0
#                       16               0.0 -0.024716    6668.0
#                       17               0.0 -0.024716   -3154.0
#                       18               0.0 -0.024716   -1025.0
#                       19               0.0 -0.024716    -799.0
#                       20               0.0 -0.024716    1119.0
#                       21               0.0 -0.024716    -356.0

# %%
rem_avg
# Out:
# 1026703.9601754387

# %%
Data_train=Data_index[Data_index['ORD_DD']<20170928]

# %%
Data_train[['매수총호가잔량']].mean(axis=0)[0]
# Out:
# 235981.705317139
