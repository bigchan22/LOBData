# %%
import pandas as pd
import os
from source.TrainDataGeneration import append_ORD_TM,append_ORD_VOL,append_TM_GP,GetGroupDataFrame,append_STEP5
from DataInfo import ISU_list_MBRN_sum_top,MBRN_sum_top,header_df
from datetime import datetime

# %%
path_dir = '/Data/LOBData/CollectedRawData/MBRN_sum_top1516/'
# path_dir = '/Data/ksqord1516/'
# path_dir = '/Data/LOBData/CollectedTickData/MBRN1516/'
# ISUlist=ISU_list_MBRN_sum_top
a=os.listdir(path_dir)
a.sort()

# %%
header_df=['ISU_CD', 'ORD_DD', 'ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD', 'BLKTRD_TP_CD', '호가장처리가격',
       'ASKBID_TP_CD', 'MODCANCL_TP_CD', 'ORD_TP_CD', 'ORD_COND_CD', 'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC',
       'ASK_STEP1_BSTORD_RQTY', 'ASK_STEP2_BSTORD_PRC','ASK_STEP2_BSTORD_RQTY','ASK_STEP3_BSTORD_PRC',
       'ASK_STEP3_BSTORD_RQTY','ASK_STEP4_BSTORD_PRC', 'ASK_STEP4_BSTORD_RQTY','ASK_STEP5_BSTORD_PRC',
       'ASK_STEP5_BSTORD_RQTY',
       'BID_STEP1_BSTORD_PRC', 'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC', 'BID_STEP2_BSTORD_RQTY',
       'BID_STEP3_BSTORD_PRC', 'BID_STEP3_BSTORD_RQTY','BID_STEP4_BSTORD_PRC', 'BID_STEP4_BSTORD_RQTY',
       'BID_STEP5_BSTORD_PRC', 'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
       '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD', 'FORNINVST_TP_CD',
       'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량', '매도총호가잔량', '매수총호가잔량',
       '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금', 'AGG_TM', '시가', '고가', '저가',
       'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드', 'MKTSTAT_TP_CD', '매도10단계호가합계잔량',
       '매수10단계호가합계잔량', 'PT_TP_CD']

# %%
ISU_CD_list=[]
for filename in a[1:]:
    print(filename)
    Data=pd.read_csv(os.path.join(path_dir,filename))
    ISU_CD_list +=list(Data['ISU_CD'].value_counts().index) 
    ISU_CD_list = list(set(ISU_CD_list))
# Out:
# CollectedRawDataksqord_20150602.csv.csv
# CollectedRawDataksqord_20150603.csv.csv
# CollectedRawDataksqord_20150604.csv.csv
# /root/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# CollectedRawDataksqord_20151223.csv.csv
# CollectedRawDataksqord_20151224.csv.csv
# CollectedRawDataksqord_20151228.csv.csv
# CollectedRawDataksqord_20151229.csv.csv
# CollectedRawDataksqord_20151230.csv.csv

# %%
ISU_CD_list
# Out:
# ['KR7040670002',
#  'KR7044180008',
#  'KR7018700005',
#  'KR7043200005',
#  'KR7058820002',
#  'KR7043100007',
#  'KR7071930002',
#  'KR7052420007',
#  'KR7024810004',
#  'KR7036540003']

# %%
len(ISU_CD_list)
# Out:
# 10

# %%
groupmin=10
SaveDirPath='/Data/LOBData/CollectedTickData/ISUTickData1516/'
filename=a[0]
print(filename)
Data=pd.read_csv(os.path.join(path_dir,filename))    
for ISU_CD in ISU_CD_list:
    savename="GDF_tick"+"_"+ISU_CD+'_'+str(groupmin)+'.csv'
    Data[Data['ISU_CD']==ISU_CD].to_csv(SaveDirPath+savename,index=False)

for filename in a[1:]:
    print(filename)
    Data=pd.read_csv(os.path.join(path_dir,filename))    
    for ISU_CD in ISU_CD_list:
        savename="GDF_tick"+"_"+ISU_CD+'_'+str(groupmin)+'.csv'
        Data[Data['ISU_CD']==ISU_CD].to_csv(SaveDirPath+savename, mode='a', index=False, header=False)
# Out:
# CollectedRawDataksqord_20150601.csv.csv
# CollectedRawDataksqord_20150602.csv.csv
# CollectedRawDataksqord_20150603.csv.csv
# CollectedRawDataksqord_20150604.csv.csv
# CollectedRawDataksqord_20150605.csv.csv
# CollectedRawDataksqord_20150608.csv.csv
# CollectedRawDataksqord_20150609.csv.csv
# CollectedRawDataksqord_20150610.csv.csv
# CollectedRawDataksqord_20150611.csv.csv
# CollectedRawDataksqord_20150612.csv.csv
# CollectedRawDataksqord_20150615.csv.csv
# CollectedRawDataksqord_20150616.csv.csv
# CollectedRawDataksqord_20150617.csv.csv
# CollectedRawDataksqord_20150618.csv.csv
# CollectedRawDataksqord_20150619.csv.csv
# CollectedRawDataksqord_20150622.csv.csv
# CollectedRawDataksqord_20150623.csv.csv
# CollectedRawDataksqord_20150624.csv.csv
# CollectedRawDataksqord_20150625.csv.csv
# CollectedRawDataksqord_20150626.csv.csv
# CollectedRawDataksqord_20150629.csv.csv
# CollectedRawDataksqord_20150630.csv.csv
# CollectedRawDataksqord_20150701.csv.csv
# CollectedRawDataksqord_20150702.csv.csv
# CollectedRawDataksqord_20150703.csv.csv
# CollectedRawDataksqord_20150706.csv.csv
# CollectedRawDataksqord_20150707.csv.csv
# CollectedRawDataksqord_20150708.csv.csv
# CollectedRawDataksqord_20150709.csv.csv
# CollectedRawDataksqord_20150710.csv.csv
# CollectedRawDataksqord_20150713.csv.csv
# CollectedRawDataksqord_20150714.csv.csv
# CollectedRawDataksqord_20150715.csv.csv
# CollectedRawDataksqord_20150716.csv.csv
# CollectedRawDataksqord_20150717.csv.csv
# CollectedRawDataksqord_20150720.csv.csv
# CollectedRawDataksqord_20150721.csv.csv
# CollectedRawDataksqord_20150722.csv.csv
# CollectedRawDataksqord_20150723.csv.csv
# 1359     1196189  KR7036540003  20151230           38                  4
# 1360     1196203  KR7036540003  20151230           52                  4
# 1361     1196221  KR7036540003  20151230           70                  4
#
#       BLKTRD_TP_CD  호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD ORD_TP_CD  ...  \
# 478              0     2730             1               1         2  ...
# 479              0     2435             2               1         2  ...
# 480              0     2200             2               1         2  ...
# 481              0     2880             1               1         2  ...
# 482              0     2620             1               1         2  ...
# ...            ...      ...           ...             ...       ...  ...
# 1357             0     2310             2               1         2  ...
# 1358             0     2350             2               1         2  ...
# 1359             0     2400             2               1         2  ...
# 1360             0     2410             2               1         2  ...
# 1361             0     2470             1               1         2  ...
#
#         시가    고가    저가  ORGN_ORD_ACPT_NO  시장구분코드  자동취소처리구분코드  MKTSTAT_TP_CD  \
# 478   2435  2435  2435                 0       2           0             10
# 479   2435  2435  2435                 0       2           0             10
# 480   2435  2435  2435                 0       2           0             10
# 481   2435  2435  2435                 0       2           0             10
# 482   2435  2435  2435                 0       2           0             10
# ...    ...   ...   ...               ...     ...         ...            ...
# 1357  2470  2470  2420                 0       2           0             70
# 1358     0  2460  2460                 0       2           0             70
# 1359     0  2460  2460                 0       2           0             70
# 1360     0  2460  2460                 0       2           0             70
# 1361     0  2460  2455                 0       2           0             70
#
#       매도10단계호가합계잔량  매수10단계호가합계잔량  PT_TP_CD
# 478              0             0         0
# 479              0             0         0
# 480              0             0         0
# 481              0             0         0
# 482           1192           304         0
# ...            ...           ...       ...
# 1357          1212          2643         0
# 1358          1412          2005         0
# 1359          2412          2004         0
# 1360          2174          2569         0
# 1361          8301          2542         0
#
# [884 rows x 62 columns]

# %%
data=pd.read_csv(SaveDirPath+savename)
# Out:
# /root/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#         Unnamed: 0        ISU_CD    ORD_DD  ORD_ACPT_NO  REGUL_OFFHR_TP_CD  \
# 0          1685973  KR7036540003  20150601            4                  2
# 1          1685974  KR7036540003  20150601            5                  2
# 2          1685975  KR7036540003  20150601            6                  2
# 3          1685976  KR7036540003  20150601            7                  2
# 4          1685980  KR7036540003  20150601           11                  2
# ...            ...           ...       ...          ...                ...
# 374169     1196174  KR7036540003  20151230           23                  4
# 374170     1196182  KR7036540003  20151230           31                  4
# 374171     1196189  KR7036540003  20151230           38                  4
# 374172     1196203  KR7036540003  20151230           52                  4
# 374173     1196221  KR7036540003  20151230           70                  4
#
#         BLKTRD_TP_CD  호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD ORD_TP_CD  ...  \
# 0                  0     4905             2               1         2  ...
# 1                  0     4905             2               1         2  ...
# 2                  0     4905             1               1         2  ...
# 3                  0     4905             2               1         2  ...
# 4                  0     4905             2               1         2  ...
# ...              ...      ...           ...             ...       ...  ...
# 374169             0     2310             2               1         2  ...
# 374170             0     2350             2               1         2  ...
# 374171             0     2400             2               1         2  ...
# 374172             0     2410             2               1         2  ...
# 374173             0     2470             1               1         2  ...
#
#           시가    고가    저가  ORGN_ORD_ACPT_NO  시장구분코드  자동취소처리구분코드  MKTSTAT_TP_CD  \
# 0       4905  4905  4905                 0       2           0             50
# 1       4905  4905  4905                 0       2           0             50
# 2       4905  4905  4905                 0       2           0             50
# 3          0  4905  4905                 0       2           0             50
# 4          0  4905  4905                 0       2           0             50
# ...      ...   ...   ...               ...     ...         ...            ...
# 374169  2470  2470  2420                 0       2           0             70
# 374170     0  2460  2460                 0       2           0             70
# 374171     0  2460  2460                 0       2           0             70
# 374172     0  2460  2460                 0       2           0             70
# 374173     0  2460  2455                 0       2           0             70
#
#         매도10단계호가합계잔량  매수10단계호가합계잔량  PT_TP_CD
# 0                  0          2780         0
# 1                  0          2880         0
# 2                  0          2880         0
# 3                  0          1380         0
# 4                  0          3680         0
# ...              ...           ...       ...
# 374169          1212          2643         0
# 374170          1412          2005         0
# 374171          2412          2004         0
# 374172          2174          2569         0
# 374173          8301          2542         0
#
# [374174 rows x 62 columns]

# %% [markdown]
# for ISU_CD in ISU_CD_list:
#     print(SaveDirPath+savename)
#     GDF.to_csv(SaveDirPath+savename)
#     with open(SaveDirPath+'DataInformation.txt', "a+") as f:
#         f.write(savename+'\t'+path_dir+'\n')
#         f.write(str(groupmin)+'\n')
#         for col in groupcolumns:
#             f.write(str(col)+'\t')
#         f.write('\n')

# %%
Data
# Out:
#       Unnamed: 0        ISU_CD    ORD_DD  ORD_ACPT_NO  REGUL_OFFHR_TP_CD  \
# 0         448226  KR7018700005  20151230            5                  1
# 1         448227  KR7018700005  20151230            6                  1
# 2         448228  KR7018700005  20151230            7                  1
# 3         448229  KR7018700005  20151230            8                  1
# 4         448230  KR7018700005  20151230            9                  1
# ...          ...           ...       ...          ...                ...
# 8962     3093759  KR7058820002  20151230           98                  4
# 8963     3093761  KR7058820002  20151230          100                  4
# 8964     3093764  KR7058820002  20151230          103                  4
# 8965     3093765  KR7058820002  20151230          104                  4
# 8966     3093767  KR7058820002  20151230          106                  4
#
#       BLKTRD_TP_CD  호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD ORD_TP_CD  ...  \
# 0                0     3070             1               1         2  ...
# 1                0     2785             2               1         2  ...
# 2                0     2525             2               1         2  ...
# 3                0     3385             1               1         2  ...
# 4                0     3735             1               1         2  ...
# ...            ...      ...           ...             ...       ...  ...
# 8962             0     2115             1               1         2  ...
# 8963             0     2100             2               1         2  ...
# 8964             0     2110             1               1         2  ...
# 8965             0     2100             2               1         2  ...
# 8966             0     2110             1               3         2  ...
#
#         시가    고가    저가  ORGN_ORD_ACPT_NO  시장구분코드  자동취소처리구분코드  MKTSTAT_TP_CD  \
# 0     2990  2990  2990                 0       2           0             10
# 1     2990  2990  2990                 0       2           0             10
# 2     2990  2990  2990                 0       2           0             10
# 3     2990  2990  2990                 0       2           0             10
# 4     2990  2990  2990                 0       2           0             10
# ...    ...   ...   ...               ...     ...         ...            ...
# 8962     0  2115  2100                 0       2           0             70
# 8963     0  2115  2100                 0       2           0             70
# 8964     0  2115  2100                 0       2           0             70
# 8965     0  2115  2100                 0       2           0             70
# 8966     0  2115  2100               103       2           0             70
#
#       매도10단계호가합계잔량  매수10단계호가합계잔량  PT_TP_CD
# 0                0             0         0
# 1                0             0         0
# 2                0             0         0
# 3                0             0         0
# 4                0             0         0
# ...            ...           ...       ...
# 8962           130          2291         0
# 8963           121          2391         0
# 8964           130          1938         0
# 8965           130          2038         0
# 8966           121          1790         0
#
# [8967 rows x 62 columns]

# %%
for filename in a:
    Data=pd.read_csv(os.path.join(path_dir,filename))
    Data=append_ORD_TM(Data)
    Data=append_ORD_VOL(Data)
    Data=append_TM_GP(Data,groupmin=groupmin)
    Data=append_STEP5(Data)
    GDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
    SaveDirPath='/Data/LOBData/CollectedTickData/MBRN1516/'
    now=datetime.now()
    savename="GDF_tick"+"_"+filename+'_'+str(groupmin)+'_'+str(now.month)+'_'+str(now.day)+'.csv'
    print(SaveDirPath+savename)
    GDF.to_csv(SaveDirPath+savename)
    with open(SaveDirPath+'DataInformation.txt', "a+") as f:
        f.write(savename+'\t'+path_dir+'\n')
        f.write(str(groupmin)+'\n')
        for col in groupcolumns:
            f.write(str(col)+'\t')
        f.write('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1455045/4062681300.py in <module>
#       5     Data=append_TM_GP(Data,groupmin=groupmin)
#       6     Data=append_STEP5(Data)
# ----> 7     GDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
#       8     SaveDirPath='/Data/LOBData/CollectedTickData/MBRN1516/'
#       9     now=datetime.now()
#
# NameError: name 'groupcolumns' is not defined

# %%
GDF

# %%
bbb

# %%
filename=a[1]
Data1=pd.read_csv(os.path.join(path_dir,filename))
Data=append_ORD_TM(Data1)
Data=append_ORD_VOL(Data)
Data=append_TM_GP(Data,groupmin=groupmin)
Data=append_STEP5(Data)
GDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
for filename in a[2:]:
    Data1=pd.read_csv(os.path.join(path_dir,filename))
    Data=append_ORD_TM(Data1)
    Data=append_ORD_VOL(Data)
    Data=append_TM_GP(Data,groupmin=groupmin)
    Data=append_STEP5(Data)
    TGDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
    GDF=pd.concat([GDF,TGDF])

# %%
a[1]

# %% [markdown]
# Data1=pd.read_csv('CollectedData/2022_3_20_22_25.csv')
# Data=append_ORD_TM(Data1)
# Data=append_ORD_VOL(Data)
# Data=append_TM_GP(Data,groupmin=groupmin)
# Data=append_STEP5(Data)
# GDF2=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)

# %% [markdown]
# Data1=pd.read_csv('CollectedData/2022_3_20_22_33.csv')
# Data=append_ORD_TM(Data1)
# Data=append_ORD_VOL(Data)
# Data=append_TM_GP(Data,groupmin=groupmin)
# Data=append_STEP5(Data)
# GDF3=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)

# %%
GDF['TM_GP'].max()

# %%
GDF.head(20)

# %% [markdown]
# GDF=pd.concat([GDF1,GDF2,GDF3])

# %%
from datetime import datetime

# %%
SaveDirPath='/Data/LOBData/CollectedTickData/'
now=datetime.now()
filename="GDF"+str(now.year)+'_'+str(now.month)+'_'+str(now.day)+'_'+str(now.hour)+'_'+str(now.minute)+'.csv'
print(SaveDirPath+filename)
GDF.to_csv(SaveDirPath+filename)

# %% [markdown]
# a=[]
