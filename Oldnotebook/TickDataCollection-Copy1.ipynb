# %%
import pandas as pd
import os
from source.TrainDataGeneration import append_ORD_TM,append_ORD_VOL,append_TM_GP,GetGroupDataFrame,append_STEP5
from DataInfo import ISU_list_MBRN_sum_top,MBRN_sum_top,header_df
from datetime import datetime

# %%
# path_dir = '/Data/LOBData/CollectedRawData/'
path_dir = '/Data/ksqord/'
# ISUlist=ISU_list_MBRN_sum_top
a=os.listdir(path_dir)
a.sort()

# %%
columns=header_df+['ORD_TM',
       'ORD_VOL', 'TM_GP', '매도5단계호가합계잔량', '매수5단계호가합계잔량']

# %%
groupcolumns=['ORD_DD','ISU_CD','TM_GP']
sumcolumns=[]
meancolumns=['ORD_ACPT_NO', 'REGUL_OFFHR_TP_CD', 'BLKTRD_TP_CD', '호가장처리가격',
       'ASKBID_TP_CD', 'MODCANCL_TP_CD',  'ORD_COND_CD', 'INVST_TP_CD', 'ASK_STEP1_BSTORD_PRC',
       'ASK_STEP1_BSTORD_RQTY', 'ASK_STEP2_BSTORD_PRC','ASK_STEP2_BSTORD_RQTY','ASK_STEP3_BSTORD_PRC',
       'ASK_STEP3_BSTORD_RQTY','ASK_STEP4_BSTORD_PRC', 'ASK_STEP4_BSTORD_RQTY','ASK_STEP5_BSTORD_PRC',
       'ASK_STEP5_BSTORD_RQTY',
       'BID_STEP1_BSTORD_PRC', 'BID_STEP1_BSTORD_RQTY', 'BID_STEP2_BSTORD_PRC', 'BID_STEP2_BSTORD_RQTY',
       'BID_STEP3_BSTORD_PRC', 'BID_STEP3_BSTORD_RQTY','BID_STEP4_BSTORD_PRC', 'BID_STEP4_BSTORD_RQTY',
       'BID_STEP5_BSTORD_PRC', 'BID_STEP5_BSTORD_RQTY', 'ORD_ACPT_TM', 'ORD_QTY', 'ORD_PRC',
       '호가우선순위번호', 'MBR_NO', 'BRN_NO', 'CNTR_CD', 'TRST_PRINC_TP_CD', 'FORNINVST_TP_CD',
       'ORD_MEDIA_TP_CD', '회원사주문시각', '예상체결가격', '예상체결수량', '매도총호가잔량', '매수총호가잔량',
       '호가체결접수순서번호', '직전체결가격', '누적체결수량', '누적거래대금', 'AGG_TM', '시가', '고가', '저가',
       'ORGN_ORD_ACPT_NO', '시장구분코드', '자동취소처리구분코드', 'MKTSTAT_TP_CD', '매도10단계호가합계잔량',
       '매수10단계호가합계잔량', 'PT_TP_CD','ORD_TM',
       'ORD_VOL', '매도5단계호가합계잔량', '매수5단계호가합계잔량']
lastcolumns=['ORD_TP_CD']
lastcolumns=[column for column in columns if column not in (sumcolumns+meancolumns+groupcolumns)]

# %%
groupmin=10

# %%
for filename in a:
    Data=pd.read_csv(os.path.join(path_dir,filename),names=header_df)
    Data=append_ORD_TM(Data)
    Data=append_ORD_VOL(Data)
    Data=append_TM_GP(Data,groupmin=groupmin)
    Data=append_STEP5(Data)
    GDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
    SaveDirPath='/Data/LOBData/CollectedTickData/MBRN1516/'
    now=datetime.now()
    savename="GDF_tick"+"_"+filename+'_'+str(groupmin)+'_'+str(now.month)+'_'+str(now.day)+'.csv'
    print(SaveDirPath+savename)
    GDF.to_csv(SaveDirPath+savename)
    with open(SaveDirPath+'DataInformation.txt', "a+") as f:
        f.write(savename+'\t'+path_dir+'\n')
        f.write(str(groupmin)+'\n')
        for col in groupcolumns:
            f.write(str(col)+'\t')
        f.write('\n')
# Out:
# /root/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170601.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170602.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170605.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170607.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170608.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170609.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170612.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170613.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170614.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170615.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170616.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170619.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170620.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170621.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170622.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170623.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170626.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170627.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170628.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170629.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170630.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170703.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170704.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170705.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170706.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170707.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170710.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170711.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170712.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170713.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170714.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170717.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170718.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170719.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170720.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170721.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170724.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170725.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170726.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170727.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170728.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170731.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170801.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170802.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170803.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170804.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170807.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170808.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170809.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170810.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170811.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170814.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170816.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170817.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170818.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170821.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170822.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170823.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170824.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170825.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170828.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170829.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170830.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170831.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170901.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170904.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170905.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170906.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170907.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170908.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170911.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170912.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170913.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170914.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170915.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170918.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170919.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170920.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170921.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170922.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170925.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170926.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170927.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170928.csv_10_10_2.csv
# /Data/LOBData/CollectedTickData/MBRN1516/GDF_tick_ksqord_20170929.csv_10_10_2.csv

# %%
GDF
# Out:
#          ORD_DD        ISU_CD  TM_GP  ORD_ACPT_NO  REGUL_OFFHR_TP_CD  \
# 0      20170929  HK0000054723   -6.0         85.0                1.0
# 1      20170929  HK0000054723   -5.0        176.5                1.0
# 2      20170929  HK0000054723   -4.0        201.0                1.0
# 3      20170929  HK0000054723   -3.0        237.5                1.0
# 4      20170929  HK0000054723   -2.0        273.0                1.0
# ...         ...           ...    ...          ...                ...
# 68151  20170929  USU652221081   50.0        161.0                4.0
# 68152  20170929  USU652221081   51.0        167.0                4.0
# 68153  20170929  USU652221081   52.0        178.5                4.0
# 68154  20170929  USU652221081   53.0        193.5                4.0
# 68155  20170929  USU652221081   54.0        203.0                4.0
#
#        BLKTRD_TP_CD      호가장처리가격  ASKBID_TP_CD  MODCANCL_TP_CD  ORD_COND_CD  \
# 0               0.0   649.668639      1.568047        1.023669          0.0
# 1               0.0   678.571429      1.428571        1.000000          0.0
# 2               0.0   646.685714      1.457143        1.085714          0.0
# 3               0.0   719.157895      1.131579        1.000000          0.0
# 4               0.0   681.606061      1.454545        1.090909          0.0
# ...             ...          ...           ...             ...          ...
# 68151           0.0  1516.000000      1.400000        2.000000          0.0
# 68152           0.0  1497.857143      1.571429        1.571429          0.0
# 68153           0.0  1505.312500      1.375000        2.187500          0.0
# 68154           0.0  1493.214286      1.571429        1.642857          0.0
# 68155           0.0  1450.000000      1.600000        2.400000          0.0
#
#        ...  자동취소처리구분코드  MKTSTAT_TP_CD  매도10단계호가합계잔량  매수10단계호가합계잔량  PT_TP_CD  \
# 0      ...         0.0           10.0      0.000000      0.000000       0.0
# 1      ...         0.0           10.0    180.000000   2076.000000       0.0
# 2      ...         0.0           10.0    180.000000   2601.714286       0.0
# 3      ...         0.0           10.0    180.526316   2776.000000       0.0
# 4      ...         0.0           10.0    210.000000   3203.969697       0.0
# ...    ...         ...            ...           ...           ...       ...
# 68151  ...         0.0           70.0   9762.000000   5369.400000       0.0
# 68152  ...         0.0           70.0   9932.142857   5731.571429       0.0
# 68153  ...         0.0           70.0   9480.812500   6056.062500       0.0
# 68154  ...         0.0           70.0   5387.357143   4524.571429       0.0
# 68155  ...         0.0           70.0   4157.000000   4780.600000       0.0
#
#              ORD_TM       ORD_VOL  매도5단계호가합계잔량  매수5단계호가합계잔량  ORD_TP_CD
# 0     -3.571603e+06  9.301921e+05     0.000000     0.000000          2
# 1     -2.575229e+06  3.666120e+07   180.000000  2076.000000          2
# 2     -2.021101e+06  2.068048e+05   180.000000  2601.714286          2
# 3     -1.440921e+06  2.868950e+06   180.526316  2776.000000          2
# 4     -9.559061e+05  6.664717e+05   210.000000  3203.969697          2
# ...             ...           ...          ...          ...        ...
# 68151  3.029810e+07  4.019340e+05  9762.000000  5369.400000          2
# 68152  3.092697e+07  8.901936e+05  9932.142857  5731.571429          2
# 68153  3.149373e+07  9.155556e+05  9480.812500  6056.062500          2
# 68154  3.209588e+07  8.289586e+05  5387.357143  4524.571429          2
# 68155  3.241193e+07  8.497340e+05  4157.000000  4780.600000          2
#
# [68156 rows x 66 columns]

# %%
aaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1440948/53527890.py in <module>
# ----> 1 aaaa
#
# NameError: name 'aaaa' is not defined

# %%
bbb

# %%
filename=a[1]
Data1=pd.read_csv(os.path.join(path_dir,filename))
Data=append_ORD_TM(Data1)
Data=append_ORD_VOL(Data)
Data=append_TM_GP(Data,groupmin=groupmin)
Data=append_STEP5(Data)
GDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
for filename in a[2:]:
    Data1=pd.read_csv(os.path.join(path_dir,filename))
    Data=append_ORD_TM(Data1)
    Data=append_ORD_VOL(Data)
    Data=append_TM_GP(Data,groupmin=groupmin)
    Data=append_STEP5(Data)
    TGDF=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)
    GDF=pd.concat([GDF,TGDF])

# %%
a[1]

# %% [markdown]
# Data1=pd.read_csv('CollectedData/2022_3_20_22_25.csv')
# Data=append_ORD_TM(Data1)
# Data=append_ORD_VOL(Data)
# Data=append_TM_GP(Data,groupmin=groupmin)
# Data=append_STEP5(Data)
# GDF2=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)

# %% [markdown]
# Data1=pd.read_csv('CollectedData/2022_3_20_22_33.csv')
# Data=append_ORD_TM(Data1)
# Data=append_ORD_VOL(Data)
# Data=append_TM_GP(Data,groupmin=groupmin)
# Data=append_STEP5(Data)
# GDF3=GetGroupDataFrame(Data,groupcolumns,sumcolumns,meancolumns,lastcolumns)

# %%
GDF['TM_GP'].max()

# %%
GDF.head(20)

# %% [markdown]
# GDF=pd.concat([GDF1,GDF2,GDF3])

# %%
from datetime import datetime

# %%
SaveDirPath='/Data/LOBData/CollectedTickData/'
now=datetime.now()
filename="GDF"+str(now.year)+'_'+str(now.month)+'_'+str(now.day)+'_'+str(now.hour)+'_'+str(now.minute)+'.csv'
print(SaveDirPath+filename)
GDF.to_csv(SaveDirPath+filename)

# %% [markdown]
# a=[]
