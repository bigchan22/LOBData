# %%
### 필요 라이브러리
import os
import pandas as pd
import numpy as np
import datetime as dt
import math
import warnings
warnings.filterwarnings(action='ignore')
# save numpy array as npy file
from numpy import asarray
from numpy import save
from DataInfo import *
### 데이터 보여지는 개수 설정
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_rows', 300)

# %%
path_dir = '/Data/ksqord'
file_list1=os.listdir(path_dir)
file_list1.sort()

print(len(file_list1[1:-21]))
print(file_list1[1:-21])
file_list1 = file_list1[1:-21]
# Out:
# 64
# ['ksqord_20170601.csv', 'ksqord_20170602.csv', 'ksqord_20170605.csv', 'ksqord_20170607.csv', 'ksqord_20170608.csv', 'ksqord_20170609.csv', 'ksqord_20170612.csv', 'ksqord_20170613.csv', 'ksqord_20170614.csv', 'ksqord_20170615.csv', 'ksqord_20170616.csv', 'ksqord_20170619.csv', 'ksqord_20170620.csv', 'ksqord_20170621.csv', 'ksqord_20170622.csv', 'ksqord_20170623.csv', 'ksqord_20170626.csv', 'ksqord_20170627.csv', 'ksqord_20170628.csv', 'ksqord_20170629.csv', 'ksqord_20170630.csv', 'ksqord_20170703.csv', 'ksqord_20170704.csv', 'ksqord_20170705.csv', 'ksqord_20170706.csv', 'ksqord_20170707.csv', 'ksqord_20170710.csv', 'ksqord_20170711.csv', 'ksqord_20170712.csv', 'ksqord_20170713.csv', 'ksqord_20170714.csv', 'ksqord_20170717.csv', 'ksqord_20170718.csv', 'ksqord_20170719.csv', 'ksqord_20170720.csv', 'ksqord_20170721.csv', 'ksqord_20170724.csv', 'ksqord_20170725.csv', 'ksqord_20170726.csv', 'ksqord_20170727.csv', 'ksqord_20170728.csv', 'ksqord_20170731.csv', 'ksqord_20170801.csv', 'ksqord_20170802.csv', 'ksqord_20170803.csv', 'ksqord_20170804.csv', 'ksqord_20170807.csv', 'ksqord_20170808.csv', 'ksqord_20170809.csv', 'ksqord_20170810.csv', 'ksqord_20170811.csv', 'ksqord_20170814.csv', 'ksqord_20170816.csv', 'ksqord_20170817.csv', 'ksqord_20170818.csv', 'ksqord_20170821.csv', 'ksqord_20170822.csv', 'ksqord_20170823.csv', 'ksqord_20170824.csv', 'ksqord_20170825.csv', 'ksqord_20170828.csv', 'ksqord_20170829.csv', 'ksqord_20170830.csv', 'ksqord_20170831.csv']

# %%
path_dir = '/Data/ksqord1516'
file_list2=os.listdir(path_dir)
file_list2.sort()

print(len(file_list2[33:-31]))
print(file_list2[33:-31])
file_list2 = file_list2[33:-31]
# Out:
# 63
# ['ksqord_20150817.csv', 'ksqord_20150818.csv', 'ksqord_20150819.csv', 'ksqord_20150820.csv', 'ksqord_20150821.csv', 'ksqord_20150824.csv', 'ksqord_20150825.csv', 'ksqord_20150826.csv', 'ksqord_20150827.csv', 'ksqord_20150828.csv', 'ksqord_20150831.csv', 'ksqord_20150901.csv', 'ksqord_20150902.csv', 'ksqord_20150903.csv', 'ksqord_20150904.csv', 'ksqord_20150907.csv', 'ksqord_20150908.csv', 'ksqord_20150909.csv', 'ksqord_20150910.csv', 'ksqord_20150911.csv', 'ksqord_20150914.csv', 'ksqord_20150915.csv', 'ksqord_20150916.csv', 'ksqord_20150917.csv', 'ksqord_20150918.csv', 'ksqord_20150921.csv', 'ksqord_20150922.csv', 'ksqord_20150923.csv', 'ksqord_20150924.csv', 'ksqord_20150925.csv', 'ksqord_20150930.csv', 'ksqord_20151001.csv', 'ksqord_20151002.csv', 'ksqord_20151005.csv', 'ksqord_20151006.csv', 'ksqord_20151007.csv', 'ksqord_20151008.csv', 'ksqord_20151012.csv', 'ksqord_20151013.csv', 'ksqord_20151014.csv', 'ksqord_20151015.csv', 'ksqord_20151016.csv', 'ksqord_20151019.csv', 'ksqord_20151020.csv', 'ksqord_20151021.csv', 'ksqord_20151022.csv', 'ksqord_20151023.csv', 'ksqord_20151026.csv', 'ksqord_20151027.csv', 'ksqord_20151028.csv', 'ksqord_20151029.csv', 'ksqord_20151030.csv', 'ksqord_20151102.csv', 'ksqord_20151103.csv', 'ksqord_20151104.csv', 'ksqord_20151105.csv', 'ksqord_20151106.csv', 'ksqord_20151109.csv', 'ksqord_20151110.csv', 'ksqord_20151111.csv', 'ksqord_20151112.csv', 'ksqord_20151113.csv', 'ksqord_20151116.csv']

# %%
path_dir = '/Data/ksqord15081510/'
file_list = file_list2

# %%
columnlist=['MBR_NO','BRN_NO','ASKBID_TP_CD','MODCANCL_TP_CD','PT_TP_CD']
featlist=columnlist + ['ORD_QTY','ORD_PRC']
filename = file_list[0]
df = pd.read_csv(path_dir+'/'+filename, sep=',', names=header_df, encoding="cp949")
df = df[featlist]
df['ORD_VOL'] = df['ORD_QTY'] * df['ORD_PRC']
gdf = df.groupby(columnlist).sum()
for filename in file_list:
    print("extracting stats from", filename )
    df = pd.read_csv(path_dir+'/'+filename, sep=',', names=header_df, encoding="cp949")
    df = df[featlist]
    df['ORD_VOL'] = df['ORD_QTY'] * df['ORD_PRC']
    tgdf = df[featlist].groupby(columnlist).count()
    gdf = gdf.add(tgdf).fillna(gdf).fillna(tgdf)
    print(gdf)
# Out:
# extracting stats from ksqord_20150817.csv
#                                                      ORD_PRC  ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0          6029155   410975
#                            2              0           998156   189660
#                            3              0           665559    39988
#               2            1              0          3358098   195776
#                            2              0           576488    40006
# ...                                                      ...      ...
# 86     300    2            1              0         21290729   421782
#                            2              0          2031219    37337
#                            3              0          3759181   148874
#        999    1            1              0            44752      402
#                            3              0            22251      201
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            1              0         2.027679e+09
#                            2              0         2.042858e+08
#                            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#
# [9325 rows x 3 columns]
# extracting stats from ksqord_20150818.csv
#                                                        ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0          6029404.0  411224.0
#                            2              0           998213.0  189717.0
#                            3              0           665585.0   40014.0
#               2            1              0          3358529.0  196207.0
#                            2              0           576544.0   40062.0
# ...                                                        ...       ...
# 86     300    2            1              0         21291905.0  422958.0
#                            2              0          2031352.0   37470.0
#                            3              0          3759356.0  149049.0
#        999    1            1              0            44752.0     402.0
#                            3              0            22251.0     201.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            1              0         2.027679e+09
#                            2              0         2.042858e+08
#                            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#
# [9588 rows x 3 columns]
# extracting stats from ksqord_20150819.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6029652.0  411472.0
#                            2              0          998242.0  189746.0
#                            3              0          665622.0   40051.0
#               2            1              0         3358914.0  196592.0
#                            2              0          576587.0   40105.0
# ...                                                       ...       ...
# 86     300    2            2              0         2031534.0   37652.0
#                            3              0         3759653.0  149346.0
#        999    1            1              0           44762.0     412.0
#                            3              0           22253.0     203.0
#               2            1              0              10.0      10.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            2              0         2.042858e+08
#                            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#
# [9752 rows x 3 columns]
# extracting stats from ksqord_20150820.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6029792.0  411612.0
#                            2              0          998254.0  189758.0
#                            3              0          665635.0   40064.0
#               2            1              0         3359055.0  196733.0
#                            2              0          576608.0   40126.0
# ...                                                       ...       ...
# 86     300    2            2              0         2031689.0   37807.0
#                            3              0         3759892.0  149585.0
#        999    1            1              0           44769.0     419.0
#                            3              0           22253.0     203.0
#               2            1              0              12.0      12.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            2              0         2.042858e+08
#                            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#
# [9810 rows x 3 columns]
# extracting stats from ksqord_20150821.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6029906.0  411726.0
#                            2              0          998263.0  189767.0
#                            3              0          665643.0   40072.0
#               2            1              0         3359282.0  196960.0
#                            2              0          576646.0   40164.0
# ...                                                       ...       ...
# 86     300    2            3              0         3760177.0  149870.0
#        999    1            1              0           44775.0     425.0
#                            3              0           22255.0     205.0
#               2            1              0              24.0      24.0
#                            3              0               3.0       3.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [9928 rows x 3 columns]
# extracting stats from ksqord_20150824.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6030039.0  411859.0
#                            2              0          998292.0  189796.0
#                            3              0          665660.0   40089.0
#               2            1              0         3359473.0  197151.0
#                            2              0          576669.0   40187.0
# ...                                                       ...       ...
# 86     300    2            3              0         3760372.0  150065.0
#        999    1            1              0           44786.0     436.0
#                            3              0           22257.0     207.0
#               2            1              0              32.0      32.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [9967 rows x 3 columns]
# extracting stats from ksqord_20150825.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6030157.0  411977.0
#                            2              0          998324.0  189828.0
#                            3              0          665666.0   40095.0
#               2            1              0         3359690.0  197368.0
#                            2              0          576695.0   40213.0
# ...                                                       ...       ...
# 86     300    2            3              0         3760601.0  150294.0
#        999    1            1              0           44786.0     436.0
#                            3              0           22257.0     207.0
#               2            1              0              34.0      34.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10015 rows x 3 columns]
# extracting stats from ksqord_20150826.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6030312.0  412132.0
#                            2              0          998348.0  189852.0
#                            3              0          665677.0   40106.0
#               2            1              0         3359975.0  197653.0
#                            2              0          576740.0   40258.0
# ...                                                       ...       ...
# 86     300    2            3              0         3760799.0  150492.0
#        999    1            1              0           44786.0     436.0
#                            3              0           22257.0     207.0
#               2            1              0              34.0      34.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10032 rows x 3 columns]
# extracting stats from ksqord_20150827.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6030665.0  412485.0
#                            2              0          998466.0  189970.0
#                            3              0          665703.0   40132.0
#               2            1              0         3360281.0  197959.0
#                            2              0          576763.0   40281.0
# ...                                                       ...       ...
# 86     300    2            3              0         3761115.0  150808.0
#        999    1            1              0           44786.0     436.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10047 rows x 3 columns]
# extracting stats from ksqord_20150828.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6030847.0  412667.0
#                            2              0          998521.0  190025.0
#                            3              0          665713.0   40142.0
#               2            1              0         3360577.0  198255.0
#                            2              0          576904.0   40422.0
# ...                                                       ...       ...
# 86     300    2            3              0         3761306.0  150999.0
#        999    1            1              0           44786.0     436.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10067 rows x 3 columns]
# extracting stats from ksqord_20150831.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031017.0  412837.0
#                            2              0          998545.0  190049.0
#                            3              0          665720.0   40149.0
#               2            1              0         3360827.0  198505.0
#                            2              0          576946.0   40464.0
# ...                                                       ...       ...
# 86     300    2            3              0         3761560.0  151253.0
#        999    1            1              0           44789.0     439.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10085 rows x 3 columns]
# extracting stats from ksqord_20150901.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031167.0  412987.0
#                            2              0          998563.0  190067.0
#                            3              0          665735.0   40164.0
#               2            1              0         3361163.0  198841.0
#                            2              0          577008.0   40526.0
# ...                                                       ...       ...
# 86     300    2            3              0         3761777.0  151470.0
#        999    1            1              0           44789.0     439.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10095 rows x 3 columns]
# extracting stats from ksqord_20150902.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031346.0  413166.0
#                            2              0          998596.0  190100.0
#                            3              0          665753.0   40182.0
#               2            1              0         3361375.0  199053.0
#                            2              0          577061.0   40579.0
# ...                                                       ...       ...
# 86     300    2            3              0         3762077.0  151770.0
#        999    1            1              0           44789.0     439.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10112 rows x 3 columns]
# extracting stats from ksqord_20150903.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031566.0  413386.0
#                            2              0          998624.0  190128.0
#                            3              0          665775.0   40204.0
#               2            1              0         3361658.0  199336.0
#                            2              0          577123.0   40641.0
# ...                                                       ...       ...
# 86     300    2            3              0         3762391.0  152084.0
#        999    1            1              0           44789.0     439.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10126 rows x 3 columns]
# extracting stats from ksqord_20150904.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031785.0  413605.0
#                            2              0          998657.0  190161.0
#                            3              0          665802.0   40231.0
#               2            1              0         3361970.0  199648.0
#                            2              0          577179.0   40697.0
# ...                                                       ...       ...
# 86     300    2            3              0         3762655.0  152348.0
#        999    1            1              0           44789.0     439.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10132 rows x 3 columns]
# extracting stats from ksqord_20150907.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6031952.0  413772.0
#                            2              0          998680.0  190184.0
#                            3              0          665821.0   40250.0
#               2            1              0         3362167.0  199845.0
#                            2              0          577221.0   40739.0
# ...                                                       ...       ...
# 86     300    2            3              0         3762810.0  152503.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10136 rows x 3 columns]
# extracting stats from ksqord_20150908.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032119.0  413939.0
#                            2              0          998735.0  190239.0
#                            3              0          665835.0   40264.0
#               2            1              0         3362503.0  200181.0
#                            2              0          577252.0   40770.0
# ...                                                       ...       ...
# 86     300    2            3              0         3763049.0  152742.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10145 rows x 3 columns]
# extracting stats from ksqord_20150909.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032261.0  414081.0
#                            2              0          998806.0  190310.0
#                            3              0          665848.0   40277.0
#               2            1              0         3362734.0  200412.0
#                            2              0          577267.0   40785.0
# ...                                                       ...       ...
# 86     300    2            3              0         3763255.0  152948.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10148 rows x 3 columns]
# extracting stats from ksqord_20150910.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032446.0  414266.0
#                            2              0          998831.0  190335.0
#                            3              0          665867.0   40296.0
#               2            1              0         3362988.0  200666.0
#                            2              0          577289.0   40807.0
# ...                                                       ...       ...
# 86     300    2            3              0         3763536.0  153229.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10161 rows x 3 columns]
# extracting stats from ksqord_20150911.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032646.0  414466.0
#                            2              0          998873.0  190377.0
#                            3              0          665884.0   40313.0
#               2            1              0         3363130.0  200808.0
#                            2              0          577306.0   40824.0
# ...                                                       ...       ...
# 86     300    2            3              0         3763852.0  153545.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10176 rows x 3 columns]
# extracting stats from ksqord_20150914.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032808.0  414628.0
#                            2              0          998886.0  190390.0
#                            3              0          665894.0   40323.0
#               2            1              0         3363280.0  200958.0
#                            2              0          577327.0   40845.0
# ...                                                       ...       ...
# 86     300    2            3              0         3764065.0  153758.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10185 rows x 3 columns]
# extracting stats from ksqord_20150915.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6032941.0  414761.0
#                            2              0          998907.0  190411.0
#                            3              0          665903.0   40332.0
#               2            1              0         3363520.0  201198.0
#                            2              0          577358.0   40876.0
# ...                                                       ...       ...
# 86     300    2            3              0         3764310.0  154003.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10189 rows x 3 columns]
# extracting stats from ksqord_20150916.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6033120.0  414940.0
#                            2              0          998936.0  190440.0
#                            3              0          665910.0   40339.0
#               2            1              0         3363822.0  201500.0
#                            2              0          577399.0   40917.0
# ...                                                       ...       ...
# 86     300    2            3              0         3764658.0  154351.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10197 rows x 3 columns]
# extracting stats from ksqord_20150917.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6033346.0  415166.0
#                            2              0          999001.0  190505.0
#                            3              0          665914.0   40343.0
#               2            1              0         3364135.0  201813.0
#                            2              0          577426.0   40944.0
# ...                                                       ...       ...
# 86     300    2            3              0         3764965.0  154658.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10207 rows x 3 columns]
# extracting stats from ksqord_20150918.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6033599.0  415419.0
#                            2              0          999148.0  190652.0
#                            3              0          665929.0   40358.0
#               2            1              0         3364681.0  202359.0
#                            2              0          577507.0   41025.0
# ...                                                       ...       ...
# 86     300    2            3              0         3765329.0  155022.0
#        999    1            1              0           44791.0     441.0
#                            3              0           22257.0     207.0
#               2            1              0              35.0      35.0
#                            3              0               4.0       4.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10209 rows x 3 columns]
# extracting stats from ksqord_20150921.csv
#                                                       ORD_PRC   ORD_QTY  \
# ...
#                            3              0               7.0       7.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     300    2            3              0         6.488865e+08
#        999    1            1              0         8.950000e+06
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            3              0                  NaN
#
# [10303 rows x 3 columns]
# extracting stats from ksqord_20151023.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6038676.0  420496.0
#                            2              0         1000465.0  191969.0
#                            3              0          666474.0   40903.0
#               2            1              0         3371526.0  209204.0
#                            2              0          578396.0   41914.0
# ...                                                       ...       ...
# 86     999    1            2              0               4.0       4.0
#                            3              0           22313.0     263.0
#               2            1              0              75.0      75.0
#                            2              0               3.0       3.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10306 rows x 3 columns]
# extracting stats from ksqord_20151026.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6038897.0  420717.0
#                            2              0         1000501.0  192005.0
#                            3              0          666493.0   40922.0
#               2            1              0         3371745.0  209423.0
#                            2              0          578433.0   41951.0
# ...                                                       ...       ...
# 86     999    1            2              0               4.0       4.0
#                            3              0           22313.0     263.0
#               2            1              0              75.0      75.0
#                            2              0               3.0       3.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10311 rows x 3 columns]
# extracting stats from ksqord_20151027.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6039107.0  420927.0
#                            2              0         1000524.0  192028.0
#                            3              0          666511.0   40940.0
#               2            1              0         3371999.0  209677.0
#                            2              0          578452.0   41970.0
# ...                                                       ...       ...
# 86     999    1            2              0               4.0       4.0
#                            3              0           22315.0     265.0
#               2            1              0              80.0      80.0
#                            2              0               6.0       6.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10313 rows x 3 columns]
# extracting stats from ksqord_20151028.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6039368.0  421188.0
#                            2              0         1000567.0  192071.0
#                            3              0          666526.0   40955.0
#               2            1              0         3372266.0  209944.0
#                            2              0          578475.0   41993.0
# ...                                                       ...       ...
# 86     999    1            2              0               4.0       4.0
#                            3              0           22318.0     268.0
#               2            1              0              80.0      80.0
#                            2              0               6.0       6.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10320 rows x 3 columns]
# extracting stats from ksqord_20151029.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6039610.0  421430.0
#                            2              0         1000614.0  192118.0
#                            3              0          666554.0   40983.0
#               2            1              0         3372545.0  210223.0
#                            2              0          578499.0   42017.0
# ...                                                       ...       ...
# 86     999    1            2              0               6.0       6.0
#                            3              0           22318.0     268.0
#               2            1              0              81.0      81.0
#                            2              0               6.0       6.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10326 rows x 3 columns]
# extracting stats from ksqord_20151030.csv
#                                                       ORD_PRC   ORD_QTY  \
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         6039877.0  421697.0
#                            2              0         1000628.0  192132.0
#                            3              0          666580.0   41009.0
#               2            1              0         3372895.0  210573.0
#                            2              0          578558.0   42076.0
# ...                                                       ...       ...
# 86     999    1            2              0               6.0       6.0
#                            3              0           22318.0     268.0
#               2            1              0              81.0      81.0
#                            2              0               6.0       6.0
#                            3              0               9.0       9.0
#
#                                                          ORD_VOL
# MBR_NO BRN_NO ASKBID_TP_CD MODCANCL_TP_CD PT_TP_CD
# 1      1      1            1              0         4.196704e+09
#                            2              0         5.772562e+08
#                            3              0         3.652134e+08
#               2            1              0         1.478568e+09
#                            2              0         2.759660e+08
# ...                                                          ...
# 86     999    1            2              0                  NaN
#                            3              0         4.450000e+06
#               2            1              0                  NaN
#                            2              0                  NaN
#                            3              0                  NaN
#
# [10331 rows x 3 columns]
# extracting stats from ksqord_20151102.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479238/1118586680.py in <module>
#       8 for filename in file_list:
#       9     print("extracting stats from", filename )
# ---> 10     df = pd.read_csv(path_dir+'/'+filename, sep=',', names=header_df, encoding="cp949")
#      11     df = df[featlist]
#      12     df['ORD_VOL'] = df['ORD_QTY'] * df['ORD_PRC']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Data/ksqord15081510//ksqord_20151102.csv'

# %%
gdf.to_csv('./StatsForDataSelection/AlmostFullColumn_cnt150811')

# %%
countdf=pd.read_csv('./StatsForDataSelection/AlmostFullColumn_cnt150811')
countdf = countdf.pivot(index= ['MBR_NO','BRN_NO','ASKBID_TP_CD','PT_TP_CD'],columns=['MODCANCL_TP_CD'],values='ORD_QTY')
countdf = countdf.reset_index()
countdf=countdf.rename(columns={1: 'NEW', 2:'EDIT',3:'CANCL'})
countdf['NET'] = countdf['NEW']-countdf['CANCL']
countdf = countdf.set_index(['MBR_NO','BRN_NO'])

# %%
countdf.sum(level=[0,1]).sort_values('NET',ascending=False).index[:30]
# Out:
# MultiIndex([(12,   100),
#             (17,    29),
#             ( 2,    83),
#             ( 4,  9997),
#             (50,    64),
#             (56, 17990),
#             ( 5,   136),
#             (44,     1),
#             ( 5,   194),
#             (50,    19),
#             ( 2,   155),
#             (50,    28),
#             (42,     1),
#             (50,    35),
#             (56, 17988),
#             (36,     1),
#             (50,    86),
#             (50,    33),
#             (50,    54),
#             (12,   202),
#             (50,    78),
#             (50,    73),
#             (63,    15),
#             (50,    24),
#             ( 8,   271),
#             (50,    42),
#             (50,    17),
#             (50,    20),
#             (50,    72),
#             (50,    82)],
#            names=['MBR_NO', 'BRN_NO'])

# %%
countdf.sum(level=[0]).sort_values('NET',ascending=False).index[:30]
# Out:
# Int64Index([50,  5, 12, 17,  3,  2,  4, 30, 56, 24, 63,  8, 25, 31,  1, 21, 44,
#             36, 22, 10, 42, 71, 46, 68, 72, 58,  6,  9, 86, 13],
#            dtype='int64', name='MBR_NO')
